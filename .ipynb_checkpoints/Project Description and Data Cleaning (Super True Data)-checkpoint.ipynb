# %% [markdown]
# ### Final Proposal: Informing Fire Safety Inspections
#
# Investigating commercial building characteristics in Peoria, Illinois and their relationship to an established fire risk score (OVAP Score).
#
# #### Problem Statement
#
# The Peoria Fire Department (PFD) conducts regular inspections of non-residential buildings to assess whether they are in compliance with local fire safety code. These inspections are meant to catch fire code violations before they result in a building fire and put the lives of building occupants in danger. Every inspection generates a fire risk score called an OVAP score.
#
# The PFD does not currently have a mechanism or process for prioritizing fire inspections of non-residential buildings. In addition, inspectors currently face a substantial backlog of buildings that have not been recently inspected. This preliminary investigation is seeking to establish a model to better prioritize these inspections.
#
# We will merge data sets that include various characteristics of commercial buildings and their current OVAP score. The goal of our data science model will be to predict what a given commercial property's OVAP score will be, helping to prioritize future inspections of commercial buildings in the hope of identifying buildings before a fire incident occurs.
#
# #### Hypothesis
#
# We expect that higher OVAP scores will be related to higher building square footage, greater building age, occupancy type, building construction material, whether it is a piece of critical infrastructure, NFIRS code, and building height.
#
# #### Assumptions
#
# - Fire Inspections reports that have been carried out are complete with quality data.
# - OVAP scores will be able to calculate risk according to the below list:
# (Low OVAP Score indicates low risk of fire, high OVAP score indicates high risk fire)
# Maximum: 60 or more
# Significant: 40 to 59
# Moderate: 15 to 39
# Low: 14 or less
#
# #### Goals:
# 1. Identify to what degree various building characteristics impact the OVAP score:
# Building a predictive model based on a number of parameters including building square footage, building age, occupancy type, building construction material, whether it is a piece of critical infrastructure, NFIRS code, and building height that assigns a risk assessment to each non-residential building in the City of Peoria.
#
# #### Success Metrics:
# - Efficacy of our model to ‘successfully’ highlight properties or zones at highest risk of fire
# - Successful if the slate of properties our model predicts/prioritizes actually return an OVAP score, close to what we predicted given the data we have from 2017, upon human inspection.
# - PFD continues to pursue predictive analytics that account for building characteristics to prioritize inspections
# - Improved data collection and standardization practices.
#
# #### Risks:
# 1. Our small data set may not be generalizable to other fire-related data that the PFD has.
#
# 2. We may just be able to get all the data sets that we need, clean them, organize them, and try creating a basic (imperfect) model to start with and learn from.
#
# 3. A good model that improves performance can cause us to begin collecting biased data. For example, if the model initially identifies that buildings with deep fryers are more likely to have incidents of fires, those types of buildings would be inspected more often. If fire incidents at these buildings go down, our model would begin to tell inspectors that those types of buildings are less likely to cause fires, even while that may not be true. (This is a consideration that should impact how our model is inserted into the inspection process. We might be able to avoid this issue by using our model to complement inspectors current process, rather than replace it.)
#
# #### Limitations:
# 1. Possible Limitation: As mentioned above, the project we have in mind for our predictive model may be hindered most heavily by time. For example, our model would need to be re-evaluated and re-adjusted multiple times before implementation as a full replacement could happen. If inspectors plan to use this model to supplement their efforts then decreasing bias, among other factors, will be our top priority to ensure reliable and consistent results.
#
# Approach to Limitation: Our approach to this limitation is to create a predictive model for our project that may inform new prioritization techniques in hopes of strengthening the efficiency of the inspection process.
#
# 2. Possible Limitation: Another major limitation would be the size and scale of our training data set. For example, if we train our model from inspections collected only in 2017 then faults and errors will arise most definitely when we apply the model moving forward.
#
# #### Data Sets Used
#
# ##### Fire Inspections (2017)
# Catalogues inspection results for non-residential buildings
# Why: Inspection results give us characteristics about buildings, such as square footage, building material type, and occupancy type.
# Peoria Fire Department
#
# ###### OVAP Scores (2017)
# The result of an inspection is an OVAP score, which describes the fire risk of a building.
# Why: Knowing how building characteristics impact an OVAP score will allow us to predict the OVAP scores of buildings that haven't been inspected.
# Peoria Fire Department
#
#
# #### Expected Challenges
# #1. Scaling Data Collection / Access
# In keeping the scope small, within Peoria, we don’t anticipate any trouble acquiring or accessing relevant data. However, if we ever look to scale, acquiring testing data from other communities may prove more challenging.
# #2. Data Uniformity
# In collecting data from a couple of different partners, we anticipate a need to do some data cleaning to ensure databases are formatted similarly and line up for valid analyses. (VALIDATED)
#
# ##### Case Studies
# New Orleans - predicted fire risk to help their Fire Department prioritize where to install smoke detectors
# Article: https://datasmart.ash.harvard.edu/news/article/predicting-fire-risk-from-new-orleans-to-a-nationwide-tool-846
# Report: http://nola.gov/performance-and-accountability/nolalytics/files/full-report-on-analytics-informed-smoke-alarm-outr/
# Code (written in R, a different programming language, but the logic would still help us re-create it in Python): https://github.com/cno-opa/smoke-alarm-outreach
# Data Used: American Housing Survey (available), American Census Survey (available to us), Property Data (available to us), Fire Incident Data (available to us)
#
# ###### Pittsburg - predicting fire risk to help Fire Department prioritize fire safety inspections
# Article: http://www.govtech.com/data/Pittsburgh-Uses-Data-to-Predict-Fire-Risk.html
# Report: http://michaelmadaio.com/Metro21_FireRisk_FinalReport.pdf
# Code: https://github.com/CityofPittsburgh/fire_risk_analysis
# Data Used: Property Data (available to us), Permits, Licenses and Inspections Data (available to us), Fire Incident Data (available to us)

# %% [markdown]
# ## STEP 1: Merge the data sets below into one clean data set that can be used to perform basic exploratory data analysis.
#
# ### Data Sets Used
#
# **Fire Inspections Notes (2017)**
# Catalogues inspection results for non-residential buildings Why: How long ago an inspection occured may impact the risk of a fire in the near future.
# Peoria Fire Department
#
# **OVAP Scores (2017)**
# OVAP scores inform the Fire Department to what extent a building might be likely to have a fire incident. The OVAP scores have only been generated since new software was implemented in 2017.
# Peoria Fire Department
#
# Note: Although Fire Inspection notes and OVAP scores are connected, they cannot currently be exported to a single data set.
#
# **Building Characteristics**
# Catalogues several characteristics of all buildings, such as year built, square footage, etc. Why: Some building characteristics may impact the risk of a fire in the future. For example, older buildings may contain knob-and-tube electrical wiring, which is less safe than modern electrical wiring.
# Peoria County GIS Department / City of Peoria Information Systems Department
#
# ### __Names of the datasets that we're working with:__
#
# 1. commercial_building_list.csv - commercial buildings in the city with firezone id and firestation (Building Characteristics)
# 2. inspection_data_2017.csv - fire inspections in 2017, pulled from current Peoria Fire Department tool (Fire Inspections)
# 3. commercial_with_OVAP_score.csv - commercial buildings that have OVAP scores, pulled from current Peoria Fire Department Tool (OVAPs)

# %%
## 1. Import all 3 data sets to take a look at their columns

import pandas as pd
from pathlib import Path

## 1.a Set path for data sets

inspections_path = Path('.', 'data', 'inspection_data_2017.csv')
buildings_path = Path('.', 'data', 'commercial_property_list.csv')
OVAP_path = Path('.', 'data', 'commercial_with_OVAP_score.csv')

## 1.b Store data in variables as dataframes

inspections = pd.read_csv(inspections_path)
buildings = pd.read_csv(buildings_path)
OVAP = pd.read_csv(OVAP_path)

## 1.c Take a look at how the 3 dataframes display address information, which
## is the column we thought we wanted to join them on originally.

print(buildings.loc[:,'full_address'].head())
print(inspections.loc[:, 'Address1'].head())
print(OVAP.loc[:, 'Address'].head())
# Out:
# 0           100 WALNUT ST
# 1         400 SW WATER ST
# 2             SW WATER ST
# 3    512 SW WASHINGTON ST
# 4         542 SW ADAMS ST
# Name: full_address, dtype: object
# 0    4700 N University ST #60
# 1             100 State ST #A
# 2              1024 W MAIN ST
# 3        2607 N University ST
# 4           100 Alexander AVE
# Name: Address1, dtype: object
# 0      8875 N Knoxville AVE
# 1          Peoria, IL 61615
# 2    2200 W War Memorial DR
# 3                    #DU19A
# 4          Peoria, IL 61613
# Name: Address, dtype: object

# %%
## 2. Clean the dataframes - Removing Columns

## 2.a Remove unnecessary columns in buildings dataframe

buildings.drop(['street_number', 'street_directionality', 'street_name', 'street_type', 'owner_middleinitial'], axis=1, inplace=True)
print(buildings.columns)

## 2.b Remove unnecessary columns in OVAP dataframe

OVAP.drop(['NFF GPM', 'Flow Available'], axis=1, inplace=True)
print(OVAP.columns)

## 2.c Remove unnecessary columns in inspections dataframe - based on Roland's recommendations

inspections.drop(['Subcategory',
       'Email', 'Phone', 'FAX', 'OccupancyNotes', 'MapPage',
       'FireAlarmPanelLoc', 'MasterKeyLoc',
       'BasementPresent', 'Width', 'Length', 'GasLPGShutoffLoc',
       'ElectricalPanelLoc', 'FDConnections', 'SprinklerRoomLoc',
       'OtherLocInfo', 'WaterSupplyInfo', 'ExposureInfo', 'HazMat',
       'BuildingAccess', 'AccessProblems', 'VentilationProblems',
       'TimeNormallyOccupied', 'PrePlanNotes', 'UserOccupancyID',
       'LicenseNumber', 'NumberOfUnits', 'OccupancyLoad', 'UBCode', 'NFPACode',
       'IBCode', 'AssessorParcelNumber', 'NumberMilepost',
       'StreetPrefixDirection', 'StreetOrHighwayName', 'StreetType',
       'StreetSuffix', 'AptOrSuite', 'ISOID', 'Latitude',
       'BuildingNumber', 'Longitude',
       'AssessedValue', 'NationalGrid',
       'UtilityBillingNumber', 'RoofTypeId', 'RoofMaterialId',
       'RoofConstructionId', 'StationID', 'DispatchID',
       'Population DensityID'], axis=1, inplace=True)
print(inspections.columns)
# Out:
# Index(['feature_ID', 'lower_PIN', 'PIN', 'owner_name', 'owner_address',
#        'owner_address2', 'owner_city', 'owner_state', 'full_address', 'city',
#        'state', 'zipcode', 'tax_code', 'first_name', 'last_name',
#        'firestation', 'firezone'],
#       dtype='object')
# Index(['Occupancy Name', 'Address', 'OVAP Score'], dtype='object')
# Index(['Name', 'Address1', 'Address2', 'City', 'State', 'Zip', 'OccupancyType',
#        'BuildingHeight', 'NumberOfFloors', 'SquareFeet',
#        'CriticalInfrastructure', 'YearBuilt', 'NFIRSPropertyUse',
#        'ConstructionTypeId'],
#       dtype='object')

# %%
## 3. Clean the dataframes - Adding columns

## 3.a view the OVAP score data set

OVAP.head()

## For every inspection in The OVAP Score data set, there is row for the address,
## another rows with City, State, ZIP and, if relevant, a third row with Unit information. 
## To clean up the OVAP dataframe, we need to remove City, State, and ZIP. 
## Then, we need to add a column to the row with the inspection and address that will denote the building's unit,
## if it exists.
# Out:
#                Occupancy Name                 Address  OVAP Score
# 0  Academy of Okinawan Karate    8875 N Knoxville AVE        0.00
# 1                         NaN        Peoria, IL 61615         NaN
# 2   the former Napoli's Pizza  2200 W War Memorial DR       29.46
# 3                         NaN                  #DU19A         NaN
# 4                         NaN        Peoria, IL 61613         NaN

# %%
## 3.b Add a "Unit" column to the OVAP data set and fill it with placeholder values 'NaN'.

OVAP.insert(2, 'Unit', 'NaN')
OVAP.head()
# Out:
#                Occupancy Name                 Address Unit  OVAP Score
# 0  Academy of Okinawan Karate    8875 N Knoxville AVE  NaN        0.00
# 1                         NaN        Peoria, IL 61615  NaN         NaN
# 2   the former Napoli's Pizza  2200 W War Memorial DR  NaN       29.46
# 3                         NaN                  #DU19A  NaN         NaN
# 4                         NaN        Peoria, IL 61613  NaN         NaN

# %%
## 4. Clean the dataframes - Consolidate Unit number into proper address row.

## 4.a Write a for loop to move unit information from 'Address' column to previous row's 'Unit' column.

## Find number of rows in OVAP by saving the rows from .shape to a variable OVAP_row_length
OVAP_row_length = OVAP.shape[0]

## Create a copy of the OVAP to work with moving forward
OVAP_clean = OVAP

## Go through all rows in OVAP_clean
for row in range(0, OVAP_row_length):
    
    ## If row's Occupancy Name is a str, this means it is a row with an inspection - skip this row
    if type(OVAP_clean.loc[row, 'Occupancy Name']) == str:
        pass
    
    ## Else, the row is not an inspection row, but a row that contains either 1) city, state and zip
    ## or 2) unit information. Check to see if '#' is in the Address column of this row - if true, 
    ## this must be a row with a Unit number.
    else:
        if '#' in OVAP_clean.loc[row, 'Address']:
            
            ## If true, this is a Unit number and is moved to the previous row's Unit column.
            ## Then, drop this column.
            OVAP_clean.loc[row-1, 'Unit'] = OVAP_clean.loc[row, 'Address']
            OVAP_clean.drop(row, inplace=True)
            
        ## Else, this is City, State, and ZIP and is not needed, so it is dropped.    
        else:
            OVAP_clean.drop(row, inplace=True)
            
## See the resulting dataframe        
OVAP_clean.head(20)
# Out:
#                            Occupancy Name                     Address    Unit  \
# 0              Academy of Okinawan Karate        8875 N Knoxville AVE     NaN
# 2               the former Napoli's Pizza      2200 W War Memorial DR  #DU19A
# 5                 (Office w/ Unkown name)                 701 Main ST      #7
# 8                     (vacant mercantile)      2200 W War Memorial DR   #DU08
# 11          1505 on the Avenue Apartments           1505 N Peoria AVE     NaN
# 13                           311 SW Water             311 SW Water ST     NaN
# 15                  401 Management Office             401 SW Water ST    #201
# 18                   401 Water - CAFE 401             401 SW Water ST    #102
# 22  401 Water - Hodges Loizzi Eisenhammer             401 SW Water ST    #106
# 25                       401 Water - VOLT             401 SW Water ST    #101
# 28                               5 Senses  5037 W American Prairie DR     NaN
# 30                         8 Bit Beercade                100 State ST      #A
# 33                       A WORLD OF WINGS              1024 W MAIN ST     NaN
# 35             AAIM Employers Association             401 SW Water ST     NaN
# 37                    AAMCO Transmissions        512 NE Jefferson AVE     NaN
# 39               Aaron Simmons State Farm               318 W McClure     NaN
# 41                       Abes Carmel corn        4700 N University ST     #11
# 45                      Academy of Awards                 701 Main ST      #3
# 48                    Accel Entertainment         921 W Detweiller DR     NaN
# 50                ACPM Podiatry Group LTD         5017 N Glen Park PL     NaN
#
#     OVAP Score
# 0         0.00
# 2        29.46
# 5        29.46
# 8        21.02
# 11       39.11
# 13       33.00
# 15       31.53
# 18       30.31
# 22       30.55
# 25       27.13
# 28       27.26
# 30        0.00
# 33       37.03
# 35       28.23
# 37       47.07
# 39       31.17
# 41        0.00
# 45        0.00
# 48       24.08
# 50       33.37

# %%
## Collapse multiple units into single address and assign the maximum OVAP value of same addresses to single address.
## In the future, we could add additional features to this collapsing. OVAP score is an aggregate of all these features.

simplified_OVAP = OVAP_clean.groupby('Address')[['Occupancy Name','OVAP Score']].max()
simplified_OVAP = simplified_OVAP.reset_index()
simplified_OVAP
# Out:
#                        Address                                Occupancy Name  \
# 0                   1 Aloha LN                                      Maui Jim
# 1                    1 Elks DR                                 Els Lodge #20
# 2            100 Alexander AVE                   Alexander Street Steakhouse
# 3                 100 State ST                          S & H Floor Covering
# 4            1000 W Albany AVE                           St Philomena Church
# 5               1000 W main ST                          Whalen's Auto Center
# 6        1005 NE Jefferson AVE                          Human Service Center
# 7               1006 W main ST                          Stecher's Automotive
# 8           1009 N Sheridan RD                                  Big Top TAT2
# 9            1010 W Johnson ST  Rogy's South Side Catholic Child Care Center
# 10              1010 W main ST                           Haddad's Restaurant
# 11             1013 W Lake AVE                  Lakeview Recreational Center
# 12              1014 W main ST                                  Lins message
# 13              1016 W MAIN ST                       MCCOYS QUALITY SERVICES
# 14             1017 W Lake AVE                       Lakeview Aquatic Center
# 15              1017 W MAIN ST                                     McDONALDS
# 16             1019 W Lake AVE                     Owens Recreational Center
# 17       1020 SW Jefferson AVE                             Schaefer Electric
# 18              1020 W MAIN ST                       GYPSY LANE RETRO SALOON
# 19         1021 N Sheridan AVE                            Sam Harris Uniform
# 20          1021 N Sheridan ST                            Sam Harris Uniform
# 21          1022 N Sheridan ST                         Tuffentsamer Law Firm
# 22              1024 W MAIN ST                              A WORLD OF WINGS
# 23            1028 SW Adams ST                               Persimmon Lofts
# 24        1029 N University ST                           Simonson Apartments
# 25           1030 W Olympia DR                        RJS Constructors, Inc.
# 26                104 South ST                    Dixie Rose Country Cabaret
# 27           1040 W Olympia DR                    ZUMBALT & ASSOCIATES, INC.
# 28        10405 N Centerway ST                                      Schnucks
# 29        10408 N Centerway DR                         Verizon Digital Store
# ..                         ...                                           ...
# 775             903 W Loire CT                  Versailles Hamlet Apartments
# 776            9031 N Allen RD                                  Sports Clips
# 777              905 W Main ST                             Peoria Hydromatic
# 778             907 W Loire CT                  Versailles Hamlet Apartments
# 779       910 SW Jefferson AVE                          Fastenal Corporation
# 780        9106 N Lindbergh DR                                     Americinn
# 781            9109 N Allen RD                            MacDonald Shell #4
# 782             911 W Loire CT                  Versailles Hamlet Apartments
# 783              911 W main ST                            Muir omni graphics
# 784  912 W John H Gwynn Jr AVE                               Simons Mortuary
# 785            9129 N Allen RD                                      Aldi #70
# 786         918 W Florence AVE               Thomas Jefferson Primary School
# 787       919 NE Jefferson AVE                                Greeley School
# 788         920 N Garfield AVE                                Kemper Express
# 789             920 W Loire CT                  Versailles Hamlet Apartments
# 790        921 W Detweiller DR                           Accel Entertainment
# 791        9219 N Lindbergh DR                                        Kroger
# 792          923 N garfield ST                            steve's automotive
# 793           923 W Millman ST                               PCCEO Headstart
# 794             924 W Loire CT                  Versailles Hamlet Apartments
# 795                926 Main ST                               Glen Oak Towers
# 796             926 W Loire CT                  Versailles Hamlet Apartments
# 797             927 W Loire CT                  Versailles Hamlet Apartments
# 798             929 W Loire CT                  Versailles Hamlet Apartments
# 799             931 W Loire CT                  Versailles Hamlet Apartments
# 800        9315 N Lindbergh DR                                  CVS/Pharmacy
# 801       933 SW Washington ST              Hagerty Industrial Tool Showroom
# 802             935 W Loire CT                  Versailles Hamlet Apartments
# 803       9901 N Knoxville AVE                               The Spot Coffee
# 804           Peoria, IL 61614                         Gorenz and Associates
#
#      OVAP Score
# 0         28.60
# 1         31.41
# 2         32.51
# 3         28.60
# 4         36.67
# 5         35.57
# 6         26.00
# 7         33.73
# 8         26.33
# 9          0.00
# 10        33.73
# 11        27.13
# 12        35.57
# 13        35.20
# 14        23.83
# 15        28.97
# 16        30.68
# 17         0.00
# 18        33.00
# 19        26.28
# 20        29.33
# 21        33.73
# 22        37.03
# 23        24.78
# 24        30.00
# 25        29.21
# 26        34.10
# 27        27.87
# 28        30.92
# 29        30.68
# ..          ...
# 775       34.00
# 776       31.29
# 777       32.27
# 778       34.00
# 779       22.73
# 780       36.06
# 781       37.40
# 782       34.00
# 783       44.67
# 784       31.53
# 785       26.40
# 786       30.43
# 787       27.13
# 788       32.27
# 789       33.33
# 790       24.08
# 791       28.60
# 792       34.80
# 793       31.66
# 794       34.00
# 795       32.89
# 796       34.00
# 797       34.00
# 798       35.00
# 799       35.00
# 800       25.30
# 801        0.00
# 802       34.00
# 803       36.18
# 804       32.27
#
# [805 rows x 3 columns]

# %%
## At this point, we decided we will be joining on Name, so we drop the 'Address' and 'Unit' Columns

simplified_OVAP.drop(['Address'], axis=1, inplace=True)
simplified_OVAP
# Out:
#                                    Occupancy Name  OVAP Score
# 0                                        Maui Jim       28.60
# 1                                   Els Lodge #20       31.41
# 2                     Alexander Street Steakhouse       32.51
# 3                            S & H Floor Covering       28.60
# 4                             St Philomena Church       36.67
# 5                            Whalen's Auto Center       35.57
# 6                            Human Service Center       26.00
# 7                            Stecher's Automotive       33.73
# 8                                    Big Top TAT2       26.33
# 9    Rogy's South Side Catholic Child Care Center        0.00
# 10                            Haddad's Restaurant       33.73
# 11                   Lakeview Recreational Center       27.13
# 12                                   Lins message       35.57
# 13                        MCCOYS QUALITY SERVICES       35.20
# 14                        Lakeview Aquatic Center       23.83
# 15                                      McDONALDS       28.97
# 16                      Owens Recreational Center       30.68
# 17                              Schaefer Electric        0.00
# 18                        GYPSY LANE RETRO SALOON       33.00
# 19                             Sam Harris Uniform       26.28
# 20                             Sam Harris Uniform       29.33
# 21                          Tuffentsamer Law Firm       33.73
# 22                               A WORLD OF WINGS       37.03
# 23                                Persimmon Lofts       24.78
# 24                            Simonson Apartments       30.00
# 25                         RJS Constructors, Inc.       29.21
# 26                     Dixie Rose Country Cabaret       34.10
# 27                     ZUMBALT & ASSOCIATES, INC.       27.87
# 28                                       Schnucks       30.92
# 29                          Verizon Digital Store       30.68
# ..                                            ...         ...
# 775                  Versailles Hamlet Apartments       34.00
# 776                                  Sports Clips       31.29
# 777                             Peoria Hydromatic       32.27
# 778                  Versailles Hamlet Apartments       34.00
# 779                          Fastenal Corporation       22.73
# 780                                     Americinn       36.06
# 781                            MacDonald Shell #4       37.40
# 782                  Versailles Hamlet Apartments       34.00
# 783                            Muir omni graphics       44.67
# 784                               Simons Mortuary       31.53
# 785                                      Aldi #70       26.40
# 786               Thomas Jefferson Primary School       30.43
# 787                                Greeley School       27.13
# 788                                Kemper Express       32.27
# 789                  Versailles Hamlet Apartments       33.33
# 790                           Accel Entertainment       24.08
# 791                                        Kroger       28.60
# 792                            steve's automotive       34.80
# 793                               PCCEO Headstart       31.66
# 794                  Versailles Hamlet Apartments       34.00
# 795                               Glen Oak Towers       32.89
# 796                  Versailles Hamlet Apartments       34.00
# 797                  Versailles Hamlet Apartments       34.00
# 798                  Versailles Hamlet Apartments       35.00
# 799                  Versailles Hamlet Apartments       35.00
# 800                                  CVS/Pharmacy       25.30
# 801              Hagerty Industrial Tool Showroom        0.00
# 802                  Versailles Hamlet Apartments       34.00
# 803                               The Spot Coffee       36.18
# 804                         Gorenz and Associates       32.27
#
# [805 rows x 2 columns]

# %%
## Change name of first column in OVAP_clean to 'Name'

simplified_OVAP.columns = ['Name', 'OVAP Score']
simplified_OVAP
# Out:
#                                              Name  OVAP Score
# 0                                        Maui Jim       28.60
# 1                                   Els Lodge #20       31.41
# 2                     Alexander Street Steakhouse       32.51
# 3                            S & H Floor Covering       28.60
# 4                             St Philomena Church       36.67
# 5                            Whalen's Auto Center       35.57
# 6                            Human Service Center       26.00
# 7                            Stecher's Automotive       33.73
# 8                                    Big Top TAT2       26.33
# 9    Rogy's South Side Catholic Child Care Center        0.00
# 10                            Haddad's Restaurant       33.73
# 11                   Lakeview Recreational Center       27.13
# 12                                   Lins message       35.57
# 13                        MCCOYS QUALITY SERVICES       35.20
# 14                        Lakeview Aquatic Center       23.83
# 15                                      McDONALDS       28.97
# 16                      Owens Recreational Center       30.68
# 17                              Schaefer Electric        0.00
# 18                        GYPSY LANE RETRO SALOON       33.00
# 19                             Sam Harris Uniform       26.28
# 20                             Sam Harris Uniform       29.33
# 21                          Tuffentsamer Law Firm       33.73
# 22                               A WORLD OF WINGS       37.03
# 23                                Persimmon Lofts       24.78
# 24                            Simonson Apartments       30.00
# 25                         RJS Constructors, Inc.       29.21
# 26                     Dixie Rose Country Cabaret       34.10
# 27                     ZUMBALT & ASSOCIATES, INC.       27.87
# 28                                       Schnucks       30.92
# 29                          Verizon Digital Store       30.68
# ..                                            ...         ...
# 775                  Versailles Hamlet Apartments       34.00
# 776                                  Sports Clips       31.29
# 777                             Peoria Hydromatic       32.27
# 778                  Versailles Hamlet Apartments       34.00
# 779                          Fastenal Corporation       22.73
# 780                                     Americinn       36.06
# 781                            MacDonald Shell #4       37.40
# 782                  Versailles Hamlet Apartments       34.00
# 783                            Muir omni graphics       44.67
# 784                               Simons Mortuary       31.53
# 785                                      Aldi #70       26.40
# 786               Thomas Jefferson Primary School       30.43
# 787                                Greeley School       27.13
# 788                                Kemper Express       32.27
# 789                  Versailles Hamlet Apartments       33.33
# 790                           Accel Entertainment       24.08
# 791                                        Kroger       28.60
# 792                            steve's automotive       34.80
# 793                               PCCEO Headstart       31.66
# 794                  Versailles Hamlet Apartments       34.00
# 795                               Glen Oak Towers       32.89
# 796                  Versailles Hamlet Apartments       34.00
# 797                  Versailles Hamlet Apartments       34.00
# 798                  Versailles Hamlet Apartments       35.00
# 799                  Versailles Hamlet Apartments       35.00
# 800                                  CVS/Pharmacy       25.30
# 801              Hagerty Industrial Tool Showroom        0.00
# 802                  Versailles Hamlet Apartments       34.00
# 803                               The Spot Coffee       36.18
# 804                         Gorenz and Associates       32.27
#
# [805 rows x 2 columns]

# %%
inspections
# Out:
#                                                Name  \
# 0                                       50's Dinner
# 1                                    8 Bit Beercade
# 2                                  A WORLD OF WINGS
# 3                                        Agatucci's
# 4                       Alexander Street Steakhouse
# 5                                    Amy's on Adams
# 6                                      Anchors Away
# 7                              Antonio's Restaurant
# 8                                    Apollo Theater
# 9               Applebee's Neighborhood Grill & Bar
# 10                                   Asia Grill Inc
# 11                                  Aurelio's Pizza
# 12                              Avanti's Ristorante
# 13                        Azteca Mexican Restaurant
# 14                                      Basket Case
# 15                     Baskin Robbins/Dunkin Donuts
# 16                              Bearded Owl Brewing
# 17                             Beasley's South Fork
# 18                                          Beer 30
# 19                                           Berlin
# 20          Bethel Apostolic Church of Jesus Christ
# 21                   Bethel united methodist church
# 22                                         Biaggi"s
# 23                              Big Al's Speak Easy
# 24                                Big O's Barbeque
# 25                                         Blondies
# 26                        Blue Duck Barbeque Tavern
# 27             Blue Margarita's Mexican Bar & Grill
# 28                               Bogies Bar & Grill
# 29              Boys & Girls Club of Greater Peoria
# ...                                             ...
# 2040                                     Walk2class
# 2041                                     Walk2Class
# 2042                               Walt's Apartment
# 2043                                    Wendle Hall
# 2044                                  William Levan
# 2045                                  Williams Hall
# 2046                              Wingate by Wyndam
# 2047                               Winkler Building
# 2048                                  Winkler Lofts
# 2049                            Woodsage Apartments
# 2050                                  Woodsage Apts
# 2051                                   Wyckoff Hall
# 2052                             Amigos Auto Repair
# 2053                                     B&D Towing
# 2054                             Bluestone Building
# 2055                          Camphill Distribution
# 2056                                 Cedar Graphics
# 2057                               Connor Supply Co
# 2058              Hoover Storage (LaHood Equipment)
# 2059              Hoover Storage (LaHood Equipment)
# 2060              Hoover Storage (LaHood Equipment)
# 2061                  Pere Marquette Parking Garage
# 2062                           PHD Services Storage
# 2063                                Red Dot Storage
# 2064                                   Roy Ricketts
# 2065                                         U-Haul
# 2066                        Calihan Pork Processors
# 2067               Greater Peoria Sanitary District
# 2068  Peoria Public Schools Transportation Building
# 2069                               Stormwater Farm
#
#                            Address1  Address2    City State    Zip  \
# 0          4700 N University ST #60       NaN  Peoria    IL  61614
# 1                   100 State ST #A       NaN  Peoria    IL  61602
# 2                    1024 W MAIN ST       NaN  PEORIA    IL  61606
# 3              2607 N University ST       NaN  Peoria    IL  61614
# 4                 100 Alexander AVE       NaN  Peoria    IL  61603
# 5                  4201 SW Adams ST       NaN  Peoria    IL  61605
# 6     4100 W Willow Knolls DR #C-12       NaN  Peoria    IL  61615
# 7                    320 Liberty ST       NaN  Peoria    IL  61602
# 8                    311 Main ST #E       NaN  Peoria    IL  61602
# 9            3929 W War Memorial DR       NaN  Peoria    IL  61604
# 10          5832 N Knoxville AVE #J       NaN  Peoria    IL  61614
# 11              3821 N Sterling AVE       NaN  Peoria    IL  61604
# 12             8517 N Knoxville AVE       NaN  Peoria    IL  61603
# 13                      319 Main ST       NaN  Peoria    IL  61602
# 14                    610 W Main ST       NaN  Peoria    IL  61606
# 15              4525 N Sterling AVE       NaN  Peoria    IL  61615
# 16                  112 State ST #A       NaN  Peoria    IL  61602
# 17                 4023 SW Adams ST       NaN  Peoria    IL  61605
# 18             2422 N Knoxville AVE       NaN  Peoria    IL  61603
# 19                      627 Main ST       NaN  Peoria    IL  61602
# 20               1125 N Sheridan RD       NaN  Peoria    IL  61614
# 21             210 Richard Pryor PL       NaN  Peoria    IL  61605
# 22                  2601 W Lake AVE       NaN  Peoria    IL  61614
# 23             400 SW Jefferson AVE       NaN  Peoria    IL  61605
# 24                 3901 SW Adams ST       NaN  Peoria    IL  61605
# 25                    619 W Main ST       NaN  Peoria    IL  61606
# 26                     212 SW Water       NaN  Peoria    IL  61602
# 27                  9010 N Allen RD       NaN  Peoria    IL  61615
# 28              3000 N Sterling AVE       NaN  Peoria    IL  61604
# 29               2703 W Grinnell ST       NaN  Peoria    IL  61605
# ...                             ...       ...     ...   ...    ...
# 2040                 844 W Moss AVE       NaN  Peoria    IL  61606
# 2041                 900 W Moss AVE       NaN  Peoria    IL  61606
# 2042        2030 N University ST #B       NaN  Peoria    IL  61614
# 2043             1315 W Saint James       NaN  Peoria    IL  61606
# 2044            5010 N Sherwood AVE       NaN  Peoria    IL  61614
# 2045                812 N Duryea PL       NaN  Peoria    IL  61606
# 2046          7708 N State Route 91       NaN  Peoria    IL  61615
# 2047           733 SW Washington ST       NaN  Peoria    IL  61605
# 2048           733 SW Washington ST       NaN  Peoria    IL  61605
# 2049                5402 W Woodsage       NaN  Peoria    IL  61615
# 2050                5322 N Woodsage       NaN  Peoria    IL  61615
# 2051              934 N Elmwood AVE       NaN  Peoria    IL  61606
# 2052                833 SW Adams ST       NaN  Peoria    IL  61605
# 2053                 101 Chicago ST       NaN  Peoria    IL  61605
# 2054              1620 W Chanute RD       NaN  Peoria    IL  61615
# 2055           1620 W Chanute RD #D       NaN  Peoria    IL  61615
# 2056        8901 N Industrial RD #D       NaN  Peoria    IL  61615
# 2057               2800 NE Adams ST       NaN  Peoria    IL  61603
# 2058                809 SW Adams ST       NaN  Peoria    IL  61605
# 2059                813 SW Adams ST       NaN  Peoria    IL  61605
# 2060                819 SW Adams ST       NaN  Peoria    IL  61605
# 2061               128 SW Monroe ST       NaN  Peoria    IL  61602
# 2062                607 NE Adams ST       NaN  Peoria    IL  61603
# 2063                8101 N Hale AVE       NaN  Peoria    IL  61615
# 2064                 520 E Lake AVE       NaN  Peoria    IL  61614
# 2065           4400 N Brandywine DR       NaN  Peoria    IL  61614
# 2066                   One South ST       NaN  Peoria    IL  61605
# 2067                2322 S Darst ST       NaN  Peoria    IL  61605
# 2068            1525 W Northmoor RD       NaN  Peoria    IL  61614
# 2069                1013 SW Reed ST       NaN  Peoria    IL  61605
#
#                                           OccupancyType  BuildingHeight  \
# 0                                       A-2 Restaurants             NaN
# 1                                  A-2 taverns and Bars             NaN
# 2                                       A-2 Restaurants             NaN
# 3                                       A-2 Restaurants             NaN
# 4                                       A-2 Restaurants             NaN
# 5                                       A-2 Night Clubs             NaN
# 6                                       A-2 Restaurants            16.0
# 7                                       A-2 Restaurants             NaN
# 8                                          A-1 Theaters             NaN
# 9                                       A-2 Restaurants            25.0
# 10                                      A-2 Restaurants             NaN
# 11                                      A-2 Restaurants             NaN
# 12                                      A-2 Restaurants             NaN
# 13                                      A-2 Restaurants             NaN
# 14                                 A-2 taverns and Bars             NaN
# 15                                      A-2 Restaurants             NaN
# 16                                          B- Business             NaN
# 17                                          B- Business             NaN
# 18                                 A-2 taverns and Bars             NaN
# 19                                      A-2 Night Clubs            35.0
# 20                                         A-3 Churches             NaN
# 21                                         A-3 Churches             NaN
# 22                                      A-2 Restaurants             NaN
# 23                                      A-2 Night Clubs             NaN
# 24                                      A-2 Restaurants             NaN
# 25                                 A-2 taverns and Bars             NaN
# 26                                 A-2 taverns and Bars             NaN
# 27                                      A-2 Restaurants            30.0
# 28                                      A-2 Restaurants             NaN
# 29                                  A-3 Community Halls             NaN
# ...                                                 ...             ...
# 2040                               R-2 Apartment Houses             NaN
# 2041                               R-2 Apartment Houses             NaN
# 2042                        R-3 Single Family Residence             NaN
# 2043                                    R-2 Dormitories             NaN
# 2044  R-1 Residential occ. where occupants are trans...             NaN
# 2045                                    R-2 Dormitories             NaN
# 2046                                          R-1 Hotel             NaN
# 2047                               R-2 Apartment Houses             NaN
# 2048                               R-2 Apartment Houses            65.0
# 2049                               R-2 Apartment Houses             NaN
# 2050                               R-2 Apartment Houses            25.0
# 2051                                    R-2 Dormitories             NaN
# 2052                       S-1 Moderate -Hazard Storage             NaN
# 2053                       S-1 Moderate -Hazard Storage            20.0
# 2054                             S-2 Low-Hazard Storage             NaN
# 2055                             S-2 Low-Hazard Storage             NaN
# 2056                       S-1 Moderate -Hazard Storage             NaN
# 2057                             S-2 Low-Hazard Storage             NaN
# 2058                             S-2 Low-Hazard Storage             NaN
# 2059                       S-1 Moderate -Hazard Storage             NaN
# 2060                       S-1 Moderate -Hazard Storage             NaN
# 2061                             S-2 Low-Hazard Storage             NaN
# 2062                             S-2 Low-Hazard Storage             NaN
# 2063                             S-2 Low-Hazard Storage             NaN
# 2064                             S-2 Low-Hazard Storage             NaN
# 2065                             S-2 Low-Hazard Storage             NaN
# 2066                  M- Miscellaneous and Utilty Group             NaN
# 2067                  M- Miscellaneous and Utilty Group            40.0
# 2068                   M-Motor Vehicle Service Stations             NaN
# 2069                             S-2 Low-Hazard Storage             NaN
#
#       NumberOfFloors  SquareFeet CriticalInfrastructure  YearBuilt  \
# 0                NaN         NaN                    NaN        NaN
# 1                1.0      1900.0                    NaN        NaN
# 2                1.0      2000.0                    NaN        NaN
# 3                NaN         NaN                    NaN        NaN
# 4                2.0     20000.0                    NaN        NaN
# 5                1.0      1500.0                    NaN        NaN
# 6                1.0      3300.0                    NaN        NaN
# 7                NaN         NaN                    NaN        NaN
# 8                3.0     25000.0                    NaN        NaN
# 9                1.0      5250.0                    NaN        NaN
# 10               NaN         NaN                    NaN        NaN
# 11               1.0      7000.0                    NaN        NaN
# 12               1.0      8300.0                    NaN        NaN
# 13               1.0      3500.0                    NaN        NaN
# 14               1.0      1200.0                    NaN        NaN
# 15               NaN         NaN                    NaN        NaN
# 16               1.0      5000.0                    NaN        NaN
# 17               NaN         NaN                    NaN        NaN
# 18               2.0      2130.0                    NaN        NaN
# 19               2.0      8000.0                    NaN        NaN
# 20               NaN         NaN                    NaN        NaN
# 21               1.0     20000.0                    NaN        NaN
# 22               1.0      6000.0                    NaN        NaN
# 23               2.0     75000.0                    NaN        NaN
# 24               NaN         NaN                    NaN        NaN
# 25               2.0      1085.0                    NaN        NaN
# 26               NaN         NaN                    NaN        NaN
# 27               1.0      4600.0                    NaN        NaN
# 28               1.0      9000.0                    NaN        NaN
# 29               NaN         NaN                    NaN        NaN
# ...              ...         ...                    ...        ...
# 2040             2.0      6500.0                    NaN        NaN
# 2041             NaN         NaN                    NaN        NaN
# 2042             NaN         NaN                    NaN        NaN
# 2043             NaN         NaN                    NaN        NaN
# 2044             NaN         NaN                    NaN        NaN
# 2045             NaN         NaN                    NaN        NaN
# 2046             3.0     49500.0                    NaN     2008.0
# 2047             NaN         NaN                    NaN        NaN
# 2048             3.0     27225.0                    NaN        NaN
# 2049             NaN         NaN                    NaN     2017.0
# 2050             3.0     15600.0                    NaN     2017.0
# 2051             NaN         NaN                    NaN        NaN
# 2052             NaN         NaN                    NaN        NaN
# 2053             1.0     22000.0                    NaN        NaN
# 2054             NaN         NaN                    NaN        NaN
# 2055             1.0     15000.0                    NaN        NaN
# 2056             NaN         NaN                    NaN        NaN
# 2057             NaN         NaN                    NaN        NaN
# 2058             NaN         NaN                    NaN        NaN
# 2059             1.0      8000.0                    NaN        NaN
# 2060             1.0      8000.0                    NaN        NaN
# 2061             4.0    117600.0                    NaN        NaN
# 2062             NaN         NaN                    NaN        NaN
# 2063             1.0         0.0                    NaN        NaN
# 2064             1.0     26000.0                    NaN     1978.0
# 2065             3.0    154500.0                    NaN     1979.0
# 2066             NaN         NaN                    NaN        NaN
# 2067             1.0     22500.0                    NaN     1977.0
# 2068             1.0      8000.0                    NaN     1950.0
# 2069             NaN         NaN                    NaN     2017.0
#
#      NFIRSPropertyUse                    ConstructionTypeId
# 0                 161  Ordinary (Joisted Masonry) Class III
# 1                 113  Ordinary (Joisted Masonry) Class III
# 2                 161  Ordinary (Joisted Masonry) Class III
# 3                 161  Ordinary (Joisted Masonry) Class III
# 4                 161                 Heavy Timber Class IV
# 5                 162  Ordinary (Joisted Masonry) Class III
# 6                 161  Non-Combustible (All Metal) Class II
# 7                 519     Non-Combustible (Masonry) Class I
# 8                 180                    Wood Frame Class V
# 9                 161  Ordinary (Joisted Masonry) Class III
# 10                NaN                                   NaN
# 11                161  Ordinary (Joisted Masonry) Class III
# 12                161  Ordinary (Joisted Masonry) Class III
# 13                161  Ordinary (Joisted Masonry) Class III
# 14                162  Ordinary (Joisted Masonry) Class III
# 15                519  Ordinary (Joisted Masonry) Class III
# 16                162  Ordinary (Joisted Masonry) Class III
# 17                549                    Wood Frame Class V
# 18                162  Ordinary (Joisted Masonry) Class III
# 19                162  Ordinary (Joisted Masonry) Class III
# 20                130  Non-Combustible (All Metal) Class II
# 21                131                                   NaN
# 22                161  Non-Combustible (All Metal) Class II
# 23                162  Non-Combustible (All Metal) Class II
# 24                161                    Wood Frame Class V
# 25                162                    Wood Frame Class V
# 26                161                    Wood Frame Class V
# 27                161  Ordinary (Joisted Masonry) Class III
# 28                161                    Wood Frame Class V
# 29                NaN                                   NaN
# ...               ...                                   ...
# 2040              429  Ordinary (Joisted Masonry) Class III
# 2041              429                                   NaN
# 2042              419  Non-Combustible (All Metal) Class II
# 2043              460                                   NaN
# 2044              NaN                                   NaN
# 2045              460                                   NaN
# 2046              449  Non-Combustible (All Metal) Class II
# 2047              429  Ordinary (Joisted Masonry) Class III
# 2048              429  Ordinary (Joisted Masonry) Class III
# 2049              429                    Wood Frame Class V
# 2050              429                    Wood Frame Class V
# 2051              460                                   NaN
# 2052              579  Ordinary (Joisted Masonry) Class III
# 2053              880  Ordinary (Joisted Masonry) Class III
# 2054              800  Non-Combustible (All Metal) Class II
# 2055              800  Non-Combustible (All Metal) Class II
# 2056              800  Non-Combustible (All Metal) Class II
# 2057              891  Ordinary (Joisted Masonry) Class III
# 2058              891  Ordinary (Joisted Masonry) Class III
# 2059              891  Ordinary (Joisted Masonry) Class III
# 2060              891  Ordinary (Joisted Masonry) Class III
# 2061              882                Fire Resistive Class I
# 2062              800  Non-Combustible (All Metal) Class II
# 2063              899                                   NaN
# 2064              891  Ordinary (Joisted Masonry) Class III
# 2065              899                    Wood Frame Class V
# 2066              NaN  Ordinary (Joisted Masonry) Class III
# 2067              648  Ordinary (Joisted Masonry) Class III
# 2068              579                    Wood Frame Class V
# 2069              938                                   NaN
#
# [2070 rows x 14 columns]

# %%
## 5. Join Dataframes - results in 5,260 rows

clean_data_set = pd.merge(simplified_OVAP, inspections, how='inner', on='Name')

print(clean_data_set.shape)

## Drop duplicates - results in 644 rows

clean_data_set = clean_data_set.drop_duplicates(subset='Name', keep='first')

print(clean_data_set.shape)
# Out:
# (5260, 15)
# (644, 15)

# %%
## Our data set still has some missing values, such as OVAP Scores that are 0, Square Footage values that are 0,
## Square Footage values that are missing altogether, Construction Type IDs, and Year Built values
## that are missing altogether.

print((clean_data_set.loc[:, 'OVAP Score'] == 0).sum())
print((clean_data_set.loc[:, 'SquareFeet'] == 0).sum())
print(clean_data_set.loc[:,'SquareFeet'].isnull().sum())
print(clean_data_set.loc[:,'YearBuilt'].isnull().sum())
print(clean_data_set.loc[:,'ConstructionTypeId'].isnull().sum())

clean_data_set.shape
# Out:
# 66
# 19
# 14
# 532
# 13
# (644, 15)

# %%
## AN ASIDE: Extract a super-true data set with only rows that contain correct values for SquareFeet and YearBuilt

super_true_data = clean_data_set.loc[((clean_data_set.loc[:,'SquareFeet'].notnull()) &
                                     (clean_data_set.loc[:,'YearBuilt'].notnull()) &
                                     (clean_data_set.loc[:, 'OVAP Score'] != 0) &
                                     (clean_data_set.loc[:, 'SquareFeet'] != 0)),:]

super_true_data.shape
# Out:
# (103, 15)

# %%
## Check to see whether any missing values remain

print((super_true_data.loc[:, 'OVAP Score'] == 0).sum())
print((super_true_data.loc[:, 'SquareFeet'] == 0).sum())
print(super_true_data.loc[:,'SquareFeet'].isnull().sum())
print(super_true_data.loc[:,'YearBuilt'].isnull().sum())
# Out:
# 0
# 0
# 0
# 0

# %%
## Add a new feature column 'BuildingAge' that uses 'YearBuilt' to determine how many years have passed
## between the year the building was built and 2017, the year the data was collected.

super_true_data.loc[:, 'BuildingAge'] = 2017 - super_true_data.loc[:, 'YearBuilt']

super_true_data
# Out:
# C:\Users\theho\Anaconda3\lib\site-packages\pandas\core\indexing.py:337: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# C:\Users\theho\Anaconda3\lib\site-packages\pandas\core\indexing.py:517: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
#                                                Name  OVAP Score  \
# 4                               St Philomena Church       36.67
# 19                     Lakeview Recreational Center       27.13
# 24                        Owens Recreational Center       30.68
# 42                            Verizon Digital Store       30.68
# 44                          St Jude Catholic School       31.90
# 45                                Jim's Steak House       33.00
# 49                        Girl Scouts Of Central IL       27.99
# 61                                     Noble Center       28.60
# 71                                   The Fieldhouse       33.00
# 74                          Pettengill Morron House       35.57
# 87                                  Charlie's Place       36.06
# 113                                       Theta Chi       22.33
# 115                          Christ Lutheran School       33.00
# 118                                       Salt Cave       36.06
# 422                               Trewyn K-8 School       30.43
# 423                              Peoria Lock & Safe       26.40
# 427                                 Garfield School       30.19
# 438   Peoria Public Schools Transportation Building       30.68
# 467                              Peoria High School       31.90
# 468                         Whittier Primary School       32.63
# 472                         Roosevelt Middle School       32.63
# 476                            Woodruff High School       32.63
# 478                                  Comfort Suites       34.96
# 480                                         Super 8       33.78
# 481                                        Mariachi       35.81
# 483                        Northmoor Primary School       33.00
# 485                                    Red Roof Inn       35.32
# 486                              Catholic Charities       27.62
# 491                                  Woodrow Wilson       34.83
# 499                       Concordia Lutheran School       28.60
# ...                                             ...         ...
# 4842                       Peoria Hebrew Day School       30.31
# 4843                    Rolling Acres Middle School       33.73
# 4851                       Mark Bills Middle School       30.43
# 4852                      St Vincent De Paul School       34.22
# 4853                 jehovah's witness kingdom hall       26.77
# 4854                   Old Orchard Trace Apartments       29.33
# 4961                        El Vista Baptist School       36.06
# 4962                          Richwoods High School       29.70
# 4964                        Lindbergh Middle School       30.43
# 4966                                  Kellar School       30.43
# 4969                Reed John Oral Surgery & Dental       33.49
# 4977                                   Hawthorn Inn       31.47
# 4979                             Lincoln K-8 School       33.73
# 4991                                St Marks School       33.00
# 5018                                 Quantum Health       27.62
# 5031                            Oak Wood Apartments       29.78
# 5040                           Holiday Inn & Suites       30.56
# 5042                                          Hyvee       34.10
# 5043                                 Charles Schwab       27.38
# 5044                              Wingate by Wyndam       30.56
# 5050                           Hampton Inn & Suites       29.70
# 5056                  Valeska Hinton Primary School       31.53
# 5058                      Von Steuben Middle School       33.73
# 5063                        Franklin Primary School       32.63
# 5064                                 Manual Academy       31.53
# 5074                                            MFC       21.76
# 5245                                      Americinn       36.06
# 5250                Thomas Jefferson Primary School       30.43
# 5251                                 Greeley School       27.13
# 5256                                Glen Oak Towers       32.89
#
#                          Address1  Address2    City State    Zip  \
# 4               1000 W Albany AVE       NaN  Peoria    IL  61614
# 19                1013 W Lake AVE       NaN  Peoria    IL  61614
# 24                1019 W Lake AVE       NaN  Peoria    IL  61614
# 42    10408 N Centerway DR #I & J       NaN  Peoria    IL  61615
# 44         10811 N Knoxvillle AVE       NaN  Peoria    IL  61615
# 45           110 SW Jefferson AVE       NaN  Peoria    IL  61603
# 49                1103 W Lake AVE       NaN  Peoria    IL  61614
# 61                1125 W Lake AVE       NaN  Peoria    IL  61614
# 71             1200 W Main ST #24       NaN  Peoria    IL  61606
# 74                1212 W Moss AVE       NaN  Peoria    IL  61606
# 87              12659 NE Adams ST       NaN  Peoria    IL  61603
# 113           1308 W Fredonia AVE       NaN  Peoria    IL  61606
# 115            1311 S Faraday AVE       NaN  Peoria    IL  61605
# 118         1314 W Pioneer PKY #C       NaN  Peoria    IL  61615
# 422            1419 S Folkers AVE       NaN  Peoria    IL  61605
# 423         1421 NE Jefferson AVE       NaN  Peoria    IL  61603
# 427              1507 S Lydia AVE       NaN  Peoria    IL  61605
# 438           1525 W Northmoor RD       NaN  Peoria    IL  61614
# 467               1615 N North ST       NaN  Peoria    IL  61604
# 468           1619 W Fredonia AVE       NaN  Peoria    IL  61606
# 472              1704 W Aiken AVE       NaN  Peoria    IL  61605
# 476             1800 NE Perry AVE       NaN  Peoria    IL  61603
# 478        1812 W War Memorial DR       NaN  Peoria    IL  61614
# 480        1816 W War Memorial DR       NaN  Peoria    IL  61614
# 481        1818 W War Memorial DR       NaN  Peoria    IL  61604
# 483           1819 W Northmoor RD       NaN  Peoria    IL  61614
# 485        1822 W War Memorial DR       NaN  Peoria    IL  61614
# 486              1825 NE Adams ST       NaN  Peoria    IL  61603
# 491       1907 W Forrest Hill AVE       NaN  Peoria    IL  61604
# 499               2000 W Glen AVE       NaN  Peoria    IL  61614
# ...                           ...       ...     ...   ...    ...
# 4842         5614 N University ST       NaN  Peoria    IL  61614
# 4843          5617 N Merrimac AVE       NaN  Peoria    IL  61614
# 4851         6001 N Frostwood PKY       NaN  Peoria    IL  61615
# 4852         6001 N University ST       NaN  Peoria    IL  61614
# 4853         6007 N Big Hollow RD       NaN  Peoria    IL  61614
# 4854        6017 N Old Orchard DR       NaN  Peoria    IL  61614
# 4961              6301 N Syler ST       NaN  Peoria    IL  61615
# 4962         6301 N University ST       NaN  Peoria    IL  61614
# 4964           6327 N Sheridan RD       NaN  Peoria    IL  61614
# 4966         6413 N Mt. Hawley RD       NaN  Peoria    IL  61614
# 4969         6714 N Frostwood PKY       NaN  Peoria    IL  61615
# 4977          6906 N Stalworth DR       NaN  Peoria    IL  61615
# 4979                  700 Mary ST       NaN  Peoria    IL  61603
# 4991           711 N Underhill ST       NaN  Peoria    IL  61606
# 5018              716 W Main ST W       NaN  Peoria    IL  61603
# 5031                740 W Joan CT       NaN  Peoria    IL  61614
# 5040     7601 N Orange Prairie RD       NaN  Peoria    IL  61615
# 5042     7610 N Orange Prairie RD       NaN  Peoria    IL  61615
# 5043   7702 N Grand Prairie DR #A       NaN  Peoria    IL  61615
# 5044        7708 N State Route 91       NaN  Peoria    IL  61615
# 5050        7806 N State Route 91       NaN  Peoria    IL  61615
# 5056    800 W Romeo B Garrett AVE       NaN  Peoria    IL  61605
# 5058       801 E Forrest Hill AVE       NaN  Peoria    IL  61603
# 5063           807 W Columbia TER       NaN  Peoria    IL  61606
# 5064            811 S Griswold ST       NaN  Peoria    IL  61605
# 5074            817 N.E. Adams ST       NaN  Peoria    IL  61603
# 5245          9106 N Lindbergh DR       NaN  Peoria    IL  61615
# 5250           918 W Florence AVE       NaN  Peoria    IL  61604
# 5251         919 NE Jefferson AVE       NaN  Peoria    IL  61603
# 5256                  926 Main ST       NaN  Peoria    IL  61602
#
#                                           OccupancyType  BuildingHeight  \
# 4                                          A-3 Churches             NaN
# 19                                 A-3 Exhibition Halls            20.0
# 24                                    A-4 Skating Rinks             NaN
# 42                                          B- Business            22.0
# 44                       E- Day care through 12th grade             NaN
# 45                                      A-2 Restaurants             NaN
# 49                                          B- Business            20.0
# 61                                          B- Business            20.0
# 71                                      A-2 Restaurants             NaN
# 74                                          A-3 Museums            50.0
# 87                          B- Fire and Police Stations            25.0
# 113                     R-2 Fraternities and Sororities             NaN
# 115                      E- Day care through 12th grade            20.0
# 118                       M- Retail or Wholesale Stores            17.0
# 422                      E- Day care through 12th grade             NaN
# 423   B- Professional Services (Architects,Attys., M...             NaN
# 427                      E- Day care through 12th grade             NaN
# 438                    M-Motor Vehicle Service Stations             NaN
# 467                      E- Day care through 12th grade             NaN
# 468                      E- Day care through 12th grade             NaN
# 472                      E- Day care through 12th grade             NaN
# 476                      E- Day care through 12th grade             NaN
# 478                                           R-1 Hotel             NaN
# 480                                           R-1 Hotel             NaN
# 481                                     A-2 Restaurants            16.0
# 483                      E- Day care through 12th grade             NaN
# 485                                           R-1 Hotel             NaN
# 486                                     A-2 Restaurants            16.0
# 491                      E- Day care through 12th grade             NaN
# 499                      E- Day care through 12th grade             NaN
# ...                                                 ...             ...
# 4842                     E- Day care through 12th grade             NaN
# 4843                     E- Day care through 12th grade             NaN
# 4851                     E- Day care through 12th grade             NaN
# 4852                     E- Day care through 12th grade             NaN
# 4853                                       A-3 Churches            10.0
# 4854                               R-2 Apartment Houses            30.0
# 4961                     E- Day care through 12th grade            25.0
# 4962                     E- Day care through 12th grade             NaN
# 4964                     E- Day care through 12th grade             NaN
# 4966                     E- Day care through 12th grade             NaN
# 4969                                        B- Business            15.0
# 4977                                      I- Adult Care            15.0
# 4979                     E- Day care through 12th grade             NaN
# 4991                     E- Day care through 12th grade            36.0
# 5018                      M- Retail or Wholesale Stores            20.0
# 5031                               R-2 Apartment Houses             NaN
# 5040                                          R-1 Hotel             NaN
# 5042                      M- Retail or Wholesale Stores            30.0
# 5043  B- Professional Services (Architects,Attys., M...             NaN
# 5044                                          R-1 Hotel             NaN
# 5050                                          R-1 Hotel             NaN
# 5056                     E- Day care through 12th grade             NaN
# 5058                     E- Day care through 12th grade             NaN
# 5063                     E- Day care through 12th grade             NaN
# 5064                     E- Day care through 12th grade             NaN
# 5074                      M- Retail or Wholesale Stores            16.0
# 5245                                          R-1 Hotel             NaN
# 5250                     E- Day care through 12th grade             NaN
# 5251                     E- Day care through 12th grade             NaN
# 5256                               R-2 Apartment Houses             NaN
#
#       NumberOfFloors  SquareFeet CriticalInfrastructure  YearBuilt  \
# 4                1.0     12600.0                    NaN     1953.0
# 19               2.0     40000.0                    NaN     1970.0
# 24               2.0    100000.0                    NaN     1980.0
# 42               1.0      3300.0                    NaN     2016.0
# 44               1.0     78200.0                    NaN     2013.0
# 45               1.0      6000.0                    NaN     1990.0
# 49               1.0      4000.0                    NaN     1967.0
# 61               2.0     40000.0                    NaN     1960.0
# 71               1.0      3500.0                    NaN     1992.0
# 74               3.0      8100.0                    NaN     1868.0
# 87               2.0     22500.0                    NaN     1469.0
# 113              2.0      7680.0                    NaN     1962.0
# 115              1.0     34275.0                    NaN     1958.0
# 118              1.0      1410.0                    NaN     2017.0
# 422              2.0    133500.0                    NaN     1949.0
# 423              1.0      2400.0                    NaN     2016.0
# 427              2.0     56300.0                    NaN     1959.0
# 438              1.0      8000.0                    NaN     1950.0
# 467              4.0    325516.0                    NaN     1916.0
# 468              2.0     71500.0                    NaN     1915.0
# 472              3.0    110500.0                    NaN     1932.0
# 476              3.0    232000.0                    NaN     1936.0
# 478              2.0     42000.0                    NaN     1991.0
# 480              3.0     30600.0                    NaN     1989.0
# 481              1.0      8500.0                    NaN     1995.0
# 483              2.0     58250.0                    NaN     1963.0
# 485              2.0     45600.0                    NaN     1979.0
# 486              1.0      5000.0                    NaN     2017.0
# 491              2.0     58700.0                    NaN     1944.0
# 499              1.0     42575.0                    NaN     1959.0
# ...              ...         ...                    ...        ...
# 4842             1.0      9350.0                    NaN     1966.0
# 4843             2.0     65366.0                    NaN     1957.0
# 4851             2.0     48300.0                    NaN     1977.0
# 4852             1.0     77500.0                    NaN     1963.0
# 4853             1.0      5625.0                    NaN     1996.0
# 4854             2.0     11100.0                    NaN     1972.0
# 4961             2.0     30000.0                    NaN     1979.0
# 4962             2.0    288642.0                    NaN     1955.0
# 4964             1.0     67525.0                    NaN     1963.0
# 4966             2.0     36945.0                    NaN     1959.0
# 4969             1.0      2000.0          Public Health     1997.0
# 4977             1.0     25000.0                    NaN     2000.0
# 4979             2.0    134777.0                    NaN     1993.0
# 4991             3.0     64350.0                    NaN     1924.0
# 5018             1.0      1500.0       Agriculture/Food     1903.0
# 5031             4.0    125000.0                    NaN     1978.0
# 5040             4.0     74100.0                    NaN     2016.0
# 5042             1.0     90000.0       Agriculture/Food     2015.0
# 5043             1.0      1385.0      Banking & Finance     2001.0
# 5044             3.0     49500.0                    NaN     2008.0
# 5050             4.0     62400.0                    NaN     2009.0
# 5056             1.0     63000.0                    NaN     1993.0
# 5058             2.0     65100.0                    NaN     1936.0
# 5063             3.0     62000.0                    NaN     1921.0
# 5064             2.0    273200.0                    NaN     1961.0
# 5074             1.0      6000.0                    NaN     1970.0
# 5245             3.0     71400.0                    NaN     2000.0
# 5250             1.0     61770.0                    NaN     1949.0
# 5251             3.0     39600.0                    NaN     1912.0
# 5256            18.0    350000.0                    NaN     1954.0
#
#      NFIRSPropertyUse                    ConstructionTypeId  BuildingAge
# 4                 131  Ordinary (Joisted Masonry) Class III         64.0
# 19                120  Non-Combustible (All Metal) Class II         47.0
# 24                114     Non-Combustible (Masonry) Class I         37.0
# 42                580  Non-Combustible (All Metal) Class II          1.0
# 44                213                    Wood Frame Class V          4.0
# 45                161  Non-Combustible (All Metal) Class II         27.0
# 49                599  Ordinary (Joisted Masonry) Class III         50.0
# 61                599     Non-Combustible (Masonry) Class I         57.0
# 71                161  Non-Combustible (All Metal) Class II         25.0
# 74                NaN                    Wood Frame Class V        149.0
# 87                557                    Wood Frame Class V        548.0
# 113               462  Ordinary (Joisted Masonry) Class III         55.0
# 115               213                    Wood Frame Class V         59.0
# 118               557                    Wood Frame Class V          0.0
# 422               213  Ordinary (Joisted Masonry) Class III         68.0
# 423               569  Non-Combustible (All Metal) Class II          1.0
# 427               213  Ordinary (Joisted Masonry) Class III         58.0
# 438               579                    Wood Frame Class V         67.0
# 467               215  Ordinary (Joisted Masonry) Class III        101.0
# 468               213  Ordinary (Joisted Masonry) Class III        102.0
# 472               213  Ordinary (Joisted Masonry) Class III         85.0
# 476               215  Ordinary (Joisted Masonry) Class III         81.0
# 478               449                    Wood Frame Class V         26.0
# 480               449                    Wood Frame Class V         28.0
# 481               161                    Wood Frame Class V         22.0
# 483               213  Ordinary (Joisted Masonry) Class III         54.0
# 485               449                    Wood Frame Class V         38.0
# 486               160  Non-Combustible (All Metal) Class II          0.0
# 491               213  Ordinary (Joisted Masonry) Class III         73.0
# 499               213  Ordinary (Joisted Masonry) Class III         58.0
# ...               ...                                   ...          ...
# 4842              131                    Wood Frame Class V         51.0
# 4843              213  Ordinary (Joisted Masonry) Class III         60.0
# 4851              213  Ordinary (Joisted Masonry) Class III         40.0
# 4852              213                    Wood Frame Class V         54.0
# 4853              100                Fire Resistive Class I         21.0
# 4854              429                    Wood Frame Class V         45.0
# 4961              213                    Wood Frame Class V         38.0
# 4962              215  Ordinary (Joisted Masonry) Class III         62.0
# 4964              213  Ordinary (Joisted Masonry) Class III         54.0
# 4966              213  Ordinary (Joisted Masonry) Class III         58.0
# 4969              342                    Wood Frame Class V         20.0
# 4977              311                Fire Resistive Class I         17.0
# 4979              213  Ordinary (Joisted Masonry) Class III         24.0
# 4991              213  Ordinary (Joisted Masonry) Class III         93.0
# 5018              519  Ordinary (Joisted Masonry) Class III        114.0
# 5031              429  Non-Combustible (All Metal) Class II         39.0
# 5040              449  Non-Combustible (All Metal) Class II          1.0
# 5042              519  Non-Combustible (All Metal) Class II          2.0
# 5043              569  Non-Combustible (All Metal) Class II         16.0
# 5044              449  Non-Combustible (All Metal) Class II          9.0
# 5050              449  Non-Combustible (All Metal) Class II          8.0
# 5056              213  Ordinary (Joisted Masonry) Class III         24.0
# 5058              213  Ordinary (Joisted Masonry) Class III         81.0
# 5063              213  Ordinary (Joisted Masonry) Class III         96.0
# 5064              215  Ordinary (Joisted Masonry) Class III         56.0
# 5074              549                Fire Resistive Class I         47.0
# 5245              449                    Wood Frame Class V         17.0
# 5250              213  Ordinary (Joisted Masonry) Class III         68.0
# 5251              213  Ordinary (Joisted Masonry) Class III        105.0
# 5256              429                Fire Resistive Class I         63.0
#
# [103 rows x 16 columns]

# %%
## Change SquareFeet to measure in Thousands

super_true_data.loc[:, 'SquareFeetK'] = (super_true_data.loc[:, 'SquareFeet'] / 1000)
# Out:
# C:\Users\theho\Anaconda3\lib\site-packages\pandas\core\indexing.py:337: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# C:\Users\theho\Anaconda3\lib\site-packages\pandas\core\indexing.py:517: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
super_true_data
# Out:
#                                                Name  OVAP Score  \
# 4                               St Philomena Church       36.67
# 19                     Lakeview Recreational Center       27.13
# 24                        Owens Recreational Center       30.68
# 42                            Verizon Digital Store       30.68
# 44                          St Jude Catholic School       31.90
# 45                                Jim's Steak House       33.00
# 49                        Girl Scouts Of Central IL       27.99
# 61                                     Noble Center       28.60
# 71                                   The Fieldhouse       33.00
# 74                          Pettengill Morron House       35.57
# 87                                  Charlie's Place       36.06
# 113                                       Theta Chi       22.33
# 115                          Christ Lutheran School       33.00
# 118                                       Salt Cave       36.06
# 422                               Trewyn K-8 School       30.43
# 423                              Peoria Lock & Safe       26.40
# 427                                 Garfield School       30.19
# 438   Peoria Public Schools Transportation Building       30.68
# 467                              Peoria High School       31.90
# 468                         Whittier Primary School       32.63
# 472                         Roosevelt Middle School       32.63
# 476                            Woodruff High School       32.63
# 478                                  Comfort Suites       34.96
# 480                                         Super 8       33.78
# 481                                        Mariachi       35.81
# 483                        Northmoor Primary School       33.00
# 485                                    Red Roof Inn       35.32
# 486                              Catholic Charities       27.62
# 491                                  Woodrow Wilson       34.83
# 499                       Concordia Lutheran School       28.60
# ...                                             ...         ...
# 4842                       Peoria Hebrew Day School       30.31
# 4843                    Rolling Acres Middle School       33.73
# 4851                       Mark Bills Middle School       30.43
# 4852                      St Vincent De Paul School       34.22
# 4853                 jehovah's witness kingdom hall       26.77
# 4854                   Old Orchard Trace Apartments       29.33
# 4961                        El Vista Baptist School       36.06
# 4962                          Richwoods High School       29.70
# 4964                        Lindbergh Middle School       30.43
# 4966                                  Kellar School       30.43
# 4969                Reed John Oral Surgery & Dental       33.49
# 4977                                   Hawthorn Inn       31.47
# 4979                             Lincoln K-8 School       33.73
# 4991                                St Marks School       33.00
# 5018                                 Quantum Health       27.62
# 5031                            Oak Wood Apartments       29.78
# 5040                           Holiday Inn & Suites       30.56
# 5042                                          Hyvee       34.10
# 5043                                 Charles Schwab       27.38
# 5044                              Wingate by Wyndam       30.56
# 5050                           Hampton Inn & Suites       29.70
# 5056                  Valeska Hinton Primary School       31.53
# 5058                      Von Steuben Middle School       33.73
# 5063                        Franklin Primary School       32.63
# 5064                                 Manual Academy       31.53
# 5074                                            MFC       21.76
# 5245                                      Americinn       36.06
# 5250                Thomas Jefferson Primary School       30.43
# 5251                                 Greeley School       27.13
# 5256                                Glen Oak Towers       32.89
#
#                          Address1  Address2    City State    Zip  \
# 4               1000 W Albany AVE       NaN  Peoria    IL  61614
# 19                1013 W Lake AVE       NaN  Peoria    IL  61614
# 24                1019 W Lake AVE       NaN  Peoria    IL  61614
# 42    10408 N Centerway DR #I & J       NaN  Peoria    IL  61615
# 44         10811 N Knoxvillle AVE       NaN  Peoria    IL  61615
# 45           110 SW Jefferson AVE       NaN  Peoria    IL  61603
# 49                1103 W Lake AVE       NaN  Peoria    IL  61614
# 61                1125 W Lake AVE       NaN  Peoria    IL  61614
# 71             1200 W Main ST #24       NaN  Peoria    IL  61606
# 74                1212 W Moss AVE       NaN  Peoria    IL  61606
# 87              12659 NE Adams ST       NaN  Peoria    IL  61603
# 113           1308 W Fredonia AVE       NaN  Peoria    IL  61606
# 115            1311 S Faraday AVE       NaN  Peoria    IL  61605
# 118         1314 W Pioneer PKY #C       NaN  Peoria    IL  61615
# 422            1419 S Folkers AVE       NaN  Peoria    IL  61605
# 423         1421 NE Jefferson AVE       NaN  Peoria    IL  61603
# 427              1507 S Lydia AVE       NaN  Peoria    IL  61605
# 438           1525 W Northmoor RD       NaN  Peoria    IL  61614
# 467               1615 N North ST       NaN  Peoria    IL  61604
# 468           1619 W Fredonia AVE       NaN  Peoria    IL  61606
# 472              1704 W Aiken AVE       NaN  Peoria    IL  61605
# 476             1800 NE Perry AVE       NaN  Peoria    IL  61603
# 478        1812 W War Memorial DR       NaN  Peoria    IL  61614
# 480        1816 W War Memorial DR       NaN  Peoria    IL  61614
# 481        1818 W War Memorial DR       NaN  Peoria    IL  61604
# 483           1819 W Northmoor RD       NaN  Peoria    IL  61614
# 485        1822 W War Memorial DR       NaN  Peoria    IL  61614
# 486              1825 NE Adams ST       NaN  Peoria    IL  61603
# 491       1907 W Forrest Hill AVE       NaN  Peoria    IL  61604
# 499               2000 W Glen AVE       NaN  Peoria    IL  61614
# ...                           ...       ...     ...   ...    ...
# 4842         5614 N University ST       NaN  Peoria    IL  61614
# 4843          5617 N Merrimac AVE       NaN  Peoria    IL  61614
# 4851         6001 N Frostwood PKY       NaN  Peoria    IL  61615
# 4852         6001 N University ST       NaN  Peoria    IL  61614
# 4853         6007 N Big Hollow RD       NaN  Peoria    IL  61614
# 4854        6017 N Old Orchard DR       NaN  Peoria    IL  61614
# 4961              6301 N Syler ST       NaN  Peoria    IL  61615
# 4962         6301 N University ST       NaN  Peoria    IL  61614
# 4964           6327 N Sheridan RD       NaN  Peoria    IL  61614
# 4966         6413 N Mt. Hawley RD       NaN  Peoria    IL  61614
# 4969         6714 N Frostwood PKY       NaN  Peoria    IL  61615
# 4977          6906 N Stalworth DR       NaN  Peoria    IL  61615
# 4979                  700 Mary ST       NaN  Peoria    IL  61603
# 4991           711 N Underhill ST       NaN  Peoria    IL  61606
# 5018              716 W Main ST W       NaN  Peoria    IL  61603
# 5031                740 W Joan CT       NaN  Peoria    IL  61614
# 5040     7601 N Orange Prairie RD       NaN  Peoria    IL  61615
# 5042     7610 N Orange Prairie RD       NaN  Peoria    IL  61615
# 5043   7702 N Grand Prairie DR #A       NaN  Peoria    IL  61615
# 5044        7708 N State Route 91       NaN  Peoria    IL  61615
# 5050        7806 N State Route 91       NaN  Peoria    IL  61615
# 5056    800 W Romeo B Garrett AVE       NaN  Peoria    IL  61605
# 5058       801 E Forrest Hill AVE       NaN  Peoria    IL  61603
# 5063           807 W Columbia TER       NaN  Peoria    IL  61606
# 5064            811 S Griswold ST       NaN  Peoria    IL  61605
# 5074            817 N.E. Adams ST       NaN  Peoria    IL  61603
# 5245          9106 N Lindbergh DR       NaN  Peoria    IL  61615
# 5250           918 W Florence AVE       NaN  Peoria    IL  61604
# 5251         919 NE Jefferson AVE       NaN  Peoria    IL  61603
# 5256                  926 Main ST       NaN  Peoria    IL  61602
#
#                                           OccupancyType  BuildingHeight  \
# 4                                          A-3 Churches             NaN
# 19                                 A-3 Exhibition Halls            20.0
# 24                                    A-4 Skating Rinks             NaN
# 42                                          B- Business            22.0
# 44                       E- Day care through 12th grade             NaN
# 45                                      A-2 Restaurants             NaN
# 49                                          B- Business            20.0
# 61                                          B- Business            20.0
# 71                                      A-2 Restaurants             NaN
# 74                                          A-3 Museums            50.0
# 87                          B- Fire and Police Stations            25.0
# 113                     R-2 Fraternities and Sororities             NaN
# 115                      E- Day care through 12th grade            20.0
# 118                       M- Retail or Wholesale Stores            17.0
# 422                      E- Day care through 12th grade             NaN
# 423   B- Professional Services (Architects,Attys., M...             NaN
# 427                      E- Day care through 12th grade             NaN
# 438                    M-Motor Vehicle Service Stations             NaN
# 467                      E- Day care through 12th grade             NaN
# 468                      E- Day care through 12th grade             NaN
# 472                      E- Day care through 12th grade             NaN
# 476                      E- Day care through 12th grade             NaN
# 478                                           R-1 Hotel             NaN
# 480                                           R-1 Hotel             NaN
# 481                                     A-2 Restaurants            16.0
# 483                      E- Day care through 12th grade             NaN
# 485                                           R-1 Hotel             NaN
# 486                                     A-2 Restaurants            16.0
# 491                      E- Day care through 12th grade             NaN
# 499                      E- Day care through 12th grade             NaN
# ...                                                 ...             ...
# 4842                     E- Day care through 12th grade             NaN
# 4843                     E- Day care through 12th grade             NaN
# 4851                     E- Day care through 12th grade             NaN
# 4852                     E- Day care through 12th grade             NaN
# 4853                                       A-3 Churches            10.0
# 4854                               R-2 Apartment Houses            30.0
# 4961                     E- Day care through 12th grade            25.0
# 4962                     E- Day care through 12th grade             NaN
# 4964                     E- Day care through 12th grade             NaN
# 4966                     E- Day care through 12th grade             NaN
# 4969                                        B- Business            15.0
# 4977                                      I- Adult Care            15.0
# 4979                     E- Day care through 12th grade             NaN
# 4991                     E- Day care through 12th grade            36.0
# 5018                      M- Retail or Wholesale Stores            20.0
# 5031                               R-2 Apartment Houses             NaN
# 5040                                          R-1 Hotel             NaN
# 5042                      M- Retail or Wholesale Stores            30.0
# 5043  B- Professional Services (Architects,Attys., M...             NaN
# 5044                                          R-1 Hotel             NaN
# 5050                                          R-1 Hotel             NaN
# 5056                     E- Day care through 12th grade             NaN
# 5058                     E- Day care through 12th grade             NaN
# 5063                     E- Day care through 12th grade             NaN
# 5064                     E- Day care through 12th grade             NaN
# 5074                      M- Retail or Wholesale Stores            16.0
# 5245                                          R-1 Hotel             NaN
# 5250                     E- Day care through 12th grade             NaN
# 5251                     E- Day care through 12th grade             NaN
# 5256                               R-2 Apartment Houses             NaN
#
#       NumberOfFloors  SquareFeet CriticalInfrastructure  YearBuilt  \
# 4                1.0     12600.0                    NaN     1953.0
# 19               2.0     40000.0                    NaN     1970.0
# 24               2.0    100000.0                    NaN     1980.0
# 42               1.0      3300.0                    NaN     2016.0
# 44               1.0     78200.0                    NaN     2013.0
# 45               1.0      6000.0                    NaN     1990.0
# 49               1.0      4000.0                    NaN     1967.0
# 61               2.0     40000.0                    NaN     1960.0
# 71               1.0      3500.0                    NaN     1992.0
# 74               3.0      8100.0                    NaN     1868.0
# 87               2.0     22500.0                    NaN     1469.0
# 113              2.0      7680.0                    NaN     1962.0
# 115              1.0     34275.0                    NaN     1958.0
# 118              1.0      1410.0                    NaN     2017.0
# 422              2.0    133500.0                    NaN     1949.0
# 423              1.0      2400.0                    NaN     2016.0
# 427              2.0     56300.0                    NaN     1959.0
# 438              1.0      8000.0                    NaN     1950.0
# 467              4.0    325516.0                    NaN     1916.0
# 468              2.0     71500.0                    NaN     1915.0
# 472              3.0    110500.0                    NaN     1932.0
# 476              3.0    232000.0                    NaN     1936.0
# 478              2.0     42000.0                    NaN     1991.0
# 480              3.0     30600.0                    NaN     1989.0
# 481              1.0      8500.0                    NaN     1995.0
# 483              2.0     58250.0                    NaN     1963.0
# 485              2.0     45600.0                    NaN     1979.0
# 486              1.0      5000.0                    NaN     2017.0
# 491              2.0     58700.0                    NaN     1944.0
# 499              1.0     42575.0                    NaN     1959.0
# ...              ...         ...                    ...        ...
# 4842             1.0      9350.0                    NaN     1966.0
# 4843             2.0     65366.0                    NaN     1957.0
# 4851             2.0     48300.0                    NaN     1977.0
# 4852             1.0     77500.0                    NaN     1963.0
# 4853             1.0      5625.0                    NaN     1996.0
# 4854             2.0     11100.0                    NaN     1972.0
# 4961             2.0     30000.0                    NaN     1979.0
# 4962             2.0    288642.0                    NaN     1955.0
# 4964             1.0     67525.0                    NaN     1963.0
# 4966             2.0     36945.0                    NaN     1959.0
# 4969             1.0      2000.0          Public Health     1997.0
# 4977             1.0     25000.0                    NaN     2000.0
# 4979             2.0    134777.0                    NaN     1993.0
# 4991             3.0     64350.0                    NaN     1924.0
# 5018             1.0      1500.0       Agriculture/Food     1903.0
# 5031             4.0    125000.0                    NaN     1978.0
# 5040             4.0     74100.0                    NaN     2016.0
# 5042             1.0     90000.0       Agriculture/Food     2015.0
# 5043             1.0      1385.0      Banking & Finance     2001.0
# 5044             3.0     49500.0                    NaN     2008.0
# 5050             4.0     62400.0                    NaN     2009.0
# 5056             1.0     63000.0                    NaN     1993.0
# 5058             2.0     65100.0                    NaN     1936.0
# 5063             3.0     62000.0                    NaN     1921.0
# 5064             2.0    273200.0                    NaN     1961.0
# 5074             1.0      6000.0                    NaN     1970.0
# 5245             3.0     71400.0                    NaN     2000.0
# 5250             1.0     61770.0                    NaN     1949.0
# 5251             3.0     39600.0                    NaN     1912.0
# 5256            18.0    350000.0                    NaN     1954.0
#
#      NFIRSPropertyUse                    ConstructionTypeId  BuildingAge  \
# 4                 131  Ordinary (Joisted Masonry) Class III         64.0
# 19                120  Non-Combustible (All Metal) Class II         47.0
# 24                114     Non-Combustible (Masonry) Class I         37.0
# 42                580  Non-Combustible (All Metal) Class II          1.0
# 44                213                    Wood Frame Class V          4.0
# 45                161  Non-Combustible (All Metal) Class II         27.0
# 49                599  Ordinary (Joisted Masonry) Class III         50.0
# 61                599     Non-Combustible (Masonry) Class I         57.0
# 71                161  Non-Combustible (All Metal) Class II         25.0
# 74                NaN                    Wood Frame Class V        149.0
# 87                557                    Wood Frame Class V        548.0
# 113               462  Ordinary (Joisted Masonry) Class III         55.0
# 115               213                    Wood Frame Class V         59.0
# 118               557                    Wood Frame Class V          0.0
# 422               213  Ordinary (Joisted Masonry) Class III         68.0
# 423               569  Non-Combustible (All Metal) Class II          1.0
# 427               213  Ordinary (Joisted Masonry) Class III         58.0
# 438               579                    Wood Frame Class V         67.0
# 467               215  Ordinary (Joisted Masonry) Class III        101.0
# 468               213  Ordinary (Joisted Masonry) Class III        102.0
# 472               213  Ordinary (Joisted Masonry) Class III         85.0
# 476               215  Ordinary (Joisted Masonry) Class III         81.0
# 478               449                    Wood Frame Class V         26.0
# 480               449                    Wood Frame Class V         28.0
# 481               161                    Wood Frame Class V         22.0
# 483               213  Ordinary (Joisted Masonry) Class III         54.0
# 485               449                    Wood Frame Class V         38.0
# 486               160  Non-Combustible (All Metal) Class II          0.0
# 491               213  Ordinary (Joisted Masonry) Class III         73.0
# 499               213  Ordinary (Joisted Masonry) Class III         58.0
# ...               ...                                   ...          ...
# 4842              131                    Wood Frame Class V         51.0
# 4843              213  Ordinary (Joisted Masonry) Class III         60.0
# 4851              213  Ordinary (Joisted Masonry) Class III         40.0
# 4852              213                    Wood Frame Class V         54.0
# 4853              100                Fire Resistive Class I         21.0
# 4854              429                    Wood Frame Class V         45.0
# 4961              213                    Wood Frame Class V         38.0
# 4962              215  Ordinary (Joisted Masonry) Class III         62.0
# 4964              213  Ordinary (Joisted Masonry) Class III         54.0
# 4966              213  Ordinary (Joisted Masonry) Class III         58.0
# 4969              342                    Wood Frame Class V         20.0
# 4977              311                Fire Resistive Class I         17.0
# 4979              213  Ordinary (Joisted Masonry) Class III         24.0
# 4991              213  Ordinary (Joisted Masonry) Class III         93.0
# 5018              519  Ordinary (Joisted Masonry) Class III        114.0
# 5031              429  Non-Combustible (All Metal) Class II         39.0
# 5040              449  Non-Combustible (All Metal) Class II          1.0
# 5042              519  Non-Combustible (All Metal) Class II          2.0
# 5043              569  Non-Combustible (All Metal) Class II         16.0
# 5044              449  Non-Combustible (All Metal) Class II          9.0
# 5050              449  Non-Combustible (All Metal) Class II          8.0
# 5056              213  Ordinary (Joisted Masonry) Class III         24.0
# 5058              213  Ordinary (Joisted Masonry) Class III         81.0
# 5063              213  Ordinary (Joisted Masonry) Class III         96.0
# 5064              215  Ordinary (Joisted Masonry) Class III         56.0
# 5074              549                Fire Resistive Class I         47.0
# 5245              449                    Wood Frame Class V         17.0
# 5250              213  Ordinary (Joisted Masonry) Class III         68.0
# 5251              213  Ordinary (Joisted Masonry) Class III        105.0
# 5256              429                Fire Resistive Class I         63.0
#
#       SquareFeetK
# 4          12.600
# 19         40.000
# 24        100.000
# 42          3.300
# 44         78.200
# 45          6.000
# 49          4.000
# 61         40.000
# 71          3.500
# 74          8.100
# 87         22.500
# 113         7.680
# 115        34.275
# 118         1.410
# 422       133.500
# 423         2.400
# 427        56.300
# 438         8.000
# 467       325.516
# 468        71.500
# 472       110.500
# 476       232.000
# 478        42.000
# 480        30.600
# 481         8.500
# 483        58.250
# 485        45.600
# 486         5.000
# 491        58.700
# 499        42.575
# ...           ...
# 4842        9.350
# 4843       65.366
# 4851       48.300
# 4852       77.500
# 4853        5.625
# 4854       11.100
# 4961       30.000
# 4962      288.642
# 4964       67.525
# 4966       36.945
# 4969        2.000
# 4977       25.000
# 4979      134.777
# 4991       64.350
# 5018        1.500
# 5031      125.000
# 5040       74.100
# 5042       90.000
# 5043        1.385
# 5044       49.500
# 5050       62.400
# 5056       63.000
# 5058       65.100
# 5063       62.000
# 5064      273.200
# 5074        6.000
# 5245       71.400
# 5250       61.770
# 5251       39.600
# 5256      350.000
#
# [103 rows x 17 columns]

# %%
## Export final clean data set to a .csv file in the 'data' directory

##clean_data_set.to_csv('data/march18_fire_data.csv')

# %%
## Predict OVAP Score from Square Footage

from sklearn.linear_model import LinearRegression                                 

# Make an instance of the LinearRegression class.
lr = LinearRegression()


# Set square footage to our X variable and what we want to predict, our OVAP score, to our y
X = super_true_data.loc[:, ['SquareFeetK']]
y = super_true_data.loc[:, ['OVAP Score']]


lr.fit(X, y)

super_true_data.loc[:, 'predictions'] = lr.predict(X)
super_true_data.loc[:, 'average_OVAP'] = super_true_data.loc[:, 'OVAP Score'].mean()
super_true_data.head(50)
# Out:
# C:\Users\theho\Anaconda3\lib\site-packages\pandas\core\indexing.py:337: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# C:\Users\theho\Anaconda3\lib\site-packages\pandas\core\indexing.py:517: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
#                                                Name  OVAP Score  \
# 4                               St Philomena Church       36.67
# 19                     Lakeview Recreational Center       27.13
# 24                        Owens Recreational Center       30.68
# 42                            Verizon Digital Store       30.68
# 44                          St Jude Catholic School       31.90
# 45                                Jim's Steak House       33.00
# 49                        Girl Scouts Of Central IL       27.99
# 61                                     Noble Center       28.60
# 71                                   The Fieldhouse       33.00
# 74                          Pettengill Morron House       35.57
# 87                                  Charlie's Place       36.06
# 113                                       Theta Chi       22.33
# 115                          Christ Lutheran School       33.00
# 118                                       Salt Cave       36.06
# 422                               Trewyn K-8 School       30.43
# 423                              Peoria Lock & Safe       26.40
# 427                                 Garfield School       30.19
# 438   Peoria Public Schools Transportation Building       30.68
# 467                              Peoria High School       31.90
# 468                         Whittier Primary School       32.63
# 472                         Roosevelt Middle School       32.63
# 476                            Woodruff High School       32.63
# 478                                  Comfort Suites       34.96
# 480                                         Super 8       33.78
# 481                                        Mariachi       35.81
# 483                        Northmoor Primary School       33.00
# 485                                    Red Roof Inn       35.32
# 486                              Catholic Charities       27.62
# 491                                  Woodrow Wilson       34.83
# 499                       Concordia Lutheran School       28.60
# 502                                   Residence Inn       38.26
# 503                            Baymont Inn & Suites       34.96
# 511                             Peoria Civic Center       46.94
# 527                                 Glen Oak School       31.53
# 529                        St Ann's Catholic Church       18.21
# 541                  vacant (Former Driving School)       39.60
# 565                                     Tyng School       32.63
# 575                          Sterling Middle School       22.73
# 592                Greater Peoria Sanitary District       30.48
# 609                              Holy Family School       30.80
# 619                               Behr Iron & Metal       22.00
# 627                 Hickory Grove Elementary School       29.60
# 678            Knoxville Center for Student Success       30.43
# 682                                 Jamieson School       29.33
# 684                                 Harrison School       30.43
# 4289                              Staybridge Suites       33.86
# 4300                      Proctor Recreation Center       33.60
# 4321  Peoria Public Schools Administration Building       30.80
# 4323                           St Philomenia School       30.19
# 4362                                       Aldi #10       30.80
#
#                           Address1  Address2    City State    Zip  \
# 4                1000 W Albany AVE       NaN  Peoria    IL  61614
# 19                 1013 W Lake AVE       NaN  Peoria    IL  61614
# 24                 1019 W Lake AVE       NaN  Peoria    IL  61614
# 42     10408 N Centerway DR #I & J       NaN  Peoria    IL  61615
# 44          10811 N Knoxvillle AVE       NaN  Peoria    IL  61615
# 45            110 SW Jefferson AVE       NaN  Peoria    IL  61603
# 49                 1103 W Lake AVE       NaN  Peoria    IL  61614
# 61                 1125 W Lake AVE       NaN  Peoria    IL  61614
# 71              1200 W Main ST #24       NaN  Peoria    IL  61606
# 74                 1212 W Moss AVE       NaN  Peoria    IL  61606
# 87               12659 NE Adams ST       NaN  Peoria    IL  61603
# 113            1308 W Fredonia AVE       NaN  Peoria    IL  61606
# 115             1311 S Faraday AVE       NaN  Peoria    IL  61605
# 118          1314 W Pioneer PKY #C       NaN  Peoria    IL  61615
# 422             1419 S Folkers AVE       NaN  Peoria    IL  61605
# 423          1421 NE Jefferson AVE       NaN  Peoria    IL  61603
# 427               1507 S Lydia AVE       NaN  Peoria    IL  61605
# 438            1525 W Northmoor RD       NaN  Peoria    IL  61614
# 467                1615 N North ST       NaN  Peoria    IL  61604
# 468            1619 W Fredonia AVE       NaN  Peoria    IL  61606
# 472               1704 W Aiken AVE       NaN  Peoria    IL  61605
# 476              1800 NE Perry AVE       NaN  Peoria    IL  61603
# 478         1812 W War Memorial DR       NaN  Peoria    IL  61614
# 480         1816 W War Memorial DR       NaN  Peoria    IL  61614
# 481         1818 W War Memorial DR       NaN  Peoria    IL  61604
# 483            1819 W Northmoor RD       NaN  Peoria    IL  61614
# 485         1822 W War Memorial DR       NaN  Peoria    IL  61614
# 486               1825 NE Adams ST       NaN  Peoria    IL  61603
# 491        1907 W Forrest Hill AVE       NaN  Peoria    IL  61604
# 499                2000 W Glen AVE       NaN  Peoria    IL  61614
# 502         2000 W War Memorial DR       NaN  Peoria    IL  61614
# 503         2002 W War Memorial DR       NaN  Peoria    IL  61614
# 511           201 SW Jefferson AVE       NaN  Peoria    IL  61602
# 527           2100 N Wisconsin AVE       NaN  Peoria    IL  61603
# 529                  2105 W Ann ST       NaN  Peoria    IL  61605
# 541   2200 W War Memorial DR #CU13       NaN  Peoria    IL  61613
# 565                  2212 W Ann ST       NaN  Peoria    IL  61605
# 575            2315 N Sterling AVE       NaN  Peoria    IL  61604
# 592                2322 S Darst ST       NaN  Peoria    IL  61605
# 609          2329 W Reservoir BLVD       NaN  Peoria    IL  61615
# 619                2424 W Clark ST       NaN  Peoria    IL  61605
# 627        2514 W Hickory Grove RD       NaN  Dunlap    IL  61525
# 678           2628 N Knoxville AVE       NaN  Peoria    IL  61603
# 682          2721 W Richwoods BLVD       NaN  Peoria    IL  61604
# 684              2727 W Krause AVE       NaN  Peoria    IL  61605
# 4289     300 W Romeo B Garrett AVE       NaN  Peoria    IL  61605
# 4300                 309 S Dusable       NaN  Peoria    IL  61605
# 4321          3202 N Wisconsin AVE       NaN  Peoria    IL  61603
# 4323                  3216 N Emery       NaN  Peoria    IL  61604
# 4362          3420 N University ST       NaN  Peoria    IL  61614
#
#                                           OccupancyType  BuildingHeight  \
# 4                                          A-3 Churches             NaN
# 19                                 A-3 Exhibition Halls            20.0
# 24                                    A-4 Skating Rinks             NaN
# 42                                          B- Business            22.0
# 44                       E- Day care through 12th grade             NaN
# 45                                      A-2 Restaurants             NaN
# 49                                          B- Business            20.0
# 61                                          B- Business            20.0
# 71                                      A-2 Restaurants             NaN
# 74                                          A-3 Museums            50.0
# 87                          B- Fire and Police Stations            25.0
# 113                     R-2 Fraternities and Sororities             NaN
# 115                      E- Day care through 12th grade            20.0
# 118                       M- Retail or Wholesale Stores            17.0
# 422                      E- Day care through 12th grade             NaN
# 423   B- Professional Services (Architects,Attys., M...             NaN
# 427                      E- Day care through 12th grade             NaN
# 438                    M-Motor Vehicle Service Stations             NaN
# 467                      E- Day care through 12th grade             NaN
# 468                      E- Day care through 12th grade             NaN
# 472                      E- Day care through 12th grade             NaN
# 476                      E- Day care through 12th grade             NaN
# 478                                           R-1 Hotel             NaN
# 480                                           R-1 Hotel             NaN
# 481                                     A-2 Restaurants            16.0
# 483                      E- Day care through 12th grade             NaN
# 485                                           R-1 Hotel             NaN
# 486                                     A-2 Restaurants            16.0
# 491                      E- Day care through 12th grade             NaN
# 499                      E- Day care through 12th grade             NaN
# 502                                           R-1 Hotel             NaN
# 503                                           R-1 Hotel             NaN
# 511                                                 A-1             NaN
# 527                      E- Day care through 12th grade             NaN
# 529                                        A-3 Churches            40.0
# 541                                         B- Business             NaN
# 565                      E- Day care through 12th grade             NaN
# 575                      E- Day care through 12th grade             NaN
# 592                   M- Miscellaneous and Utilty Group            40.0
# 609                      E- Day care through 12th grade            10.0
# 619                                         B- Business            30.0
# 627                      E- Day care through 12th grade             NaN
# 678                      E- Day care through 12th grade             NaN
# 682                      E- Day care through 12th grade             NaN
# 684                      E- Day care through 12th grade             NaN
# 4289                                          R-1 Hotel             NaN
# 4300                                 A-4 Swimming Pools             NaN
# 4321                                        B- Business             NaN
# 4323                     E- Day care through 12th grade            20.0
# 4362                                          M-Markets            22.0
#
#       NumberOfFloors  SquareFeet      CriticalInfrastructure  YearBuilt  \
# 4                1.0     12600.0                         NaN     1953.0
# 19               2.0     40000.0                         NaN     1970.0
# 24               2.0    100000.0                         NaN     1980.0
# 42               1.0      3300.0                         NaN     2016.0
# 44               1.0     78200.0                         NaN     2013.0
# 45               1.0      6000.0                         NaN     1990.0
# 49               1.0      4000.0                         NaN     1967.0
# 61               2.0     40000.0                         NaN     1960.0
# 71               1.0      3500.0                         NaN     1992.0
# 74               3.0      8100.0                         NaN     1868.0
# 87               2.0     22500.0                         NaN     1469.0
# 113              2.0      7680.0                         NaN     1962.0
# 115              1.0     34275.0                         NaN     1958.0
# 118              1.0      1410.0                         NaN     2017.0
# 422              2.0    133500.0                         NaN     1949.0
# 423              1.0      2400.0                         NaN     2016.0
# 427              2.0     56300.0                         NaN     1959.0
# 438              1.0      8000.0                         NaN     1950.0
# 467              4.0    325516.0                         NaN     1916.0
# 468              2.0     71500.0                         NaN     1915.0
# 472              3.0    110500.0                         NaN     1932.0
# 476              3.0    232000.0                         NaN     1936.0
# 478              2.0     42000.0                         NaN     1991.0
# 480              3.0     30600.0                         NaN     1989.0
# 481              1.0      8500.0                         NaN     1995.0
# 483              2.0     58250.0                         NaN     1963.0
# 485              2.0     45600.0                         NaN     1979.0
# 486              1.0      5000.0                         NaN     2017.0
# 491              2.0     58700.0                         NaN     1944.0
# 499              1.0     42575.0                         NaN     1959.0
# 502              3.0     43000.0                         NaN     1993.0
# 503              3.0     44500.0                         NaN     1989.0
# 511              5.0    996000.0                         NaN     1979.0
# 527              2.0    126000.0                         NaN     2009.0
# 529              2.0      4800.0                         NaN     1894.0
# 541              1.0      1464.0                         NaN     1973.0
# 565              2.0     62400.0                         NaN     1913.0
# 575              2.0     64600.0                         NaN     1962.0
# 592              1.0     22500.0                         NaN     1977.0
# 609              1.0     42400.0                         NaN     1956.0
# 619              1.0      3150.0                         NaN     2011.0
# 627              2.0    135000.0  National Monuments & Icons     2011.0
# 678              1.0     10650.0                         NaN     1972.0
# 682              1.0     23000.0                         NaN     1975.0
# 684              2.0     50000.0                         NaN     2007.0
# 4289             3.0     76200.0                         NaN     2001.0
# 4300             2.0     97200.0                         NaN     1913.0
# 4321             1.0     40330.0                         NaN     1972.0
# 4323             2.0     40000.0                         NaN     1948.0
# 4362             1.0     15400.0            Agriculture/Food     2016.0
#
#      NFIRSPropertyUse                    ConstructionTypeId  BuildingAge  \
# 4                 131  Ordinary (Joisted Masonry) Class III         64.0
# 19                120  Non-Combustible (All Metal) Class II         47.0
# 24                114     Non-Combustible (Masonry) Class I         37.0
# 42                580  Non-Combustible (All Metal) Class II          1.0
# 44                213                    Wood Frame Class V          4.0
# 45                161  Non-Combustible (All Metal) Class II         27.0
# 49                599  Ordinary (Joisted Masonry) Class III         50.0
# 61                599     Non-Combustible (Masonry) Class I         57.0
# 71                161  Non-Combustible (All Metal) Class II         25.0
# 74                NaN                    Wood Frame Class V        149.0
# 87                557                    Wood Frame Class V        548.0
# 113               462  Ordinary (Joisted Masonry) Class III         55.0
# 115               213                    Wood Frame Class V         59.0
# 118               557                    Wood Frame Class V          0.0
# 422               213  Ordinary (Joisted Masonry) Class III         68.0
# 423               569  Non-Combustible (All Metal) Class II          1.0
# 427               213  Ordinary (Joisted Masonry) Class III         58.0
# 438               579                    Wood Frame Class V         67.0
# 467               215  Ordinary (Joisted Masonry) Class III        101.0
# 468               213  Ordinary (Joisted Masonry) Class III        102.0
# 472               213  Ordinary (Joisted Masonry) Class III         85.0
# 476               215  Ordinary (Joisted Masonry) Class III         81.0
# 478               449                    Wood Frame Class V         26.0
# 480               449                    Wood Frame Class V         28.0
# 481               161                    Wood Frame Class V         22.0
# 483               213  Ordinary (Joisted Masonry) Class III         54.0
# 485               449                    Wood Frame Class V         38.0
# 486               160  Non-Combustible (All Metal) Class II          0.0
# 491               213  Ordinary (Joisted Masonry) Class III         73.0
# 499               213  Ordinary (Joisted Masonry) Class III         58.0
# 502               449                    Wood Frame Class V         24.0
# 503               449                    Wood Frame Class V         28.0
# 511               123  Ordinary (Joisted Masonry) Class III         38.0
# 527               213  Ordinary (Joisted Masonry) Class III          8.0
# 529               131     Non-Combustible (Masonry) Class I        123.0
# 541               599  Non-Combustible (All Metal) Class II         44.0
# 565               213  Ordinary (Joisted Masonry) Class III        104.0
# 575               213  Ordinary (Joisted Masonry) Class III         55.0
# 592               648  Ordinary (Joisted Masonry) Class III         40.0
# 609               213  Ordinary (Joisted Masonry) Class III         61.0
# 619               700     Non-Combustible (Masonry) Class I          6.0
# 627               213  Non-Combustible (All Metal) Class II          6.0
# 678               215  Ordinary (Joisted Masonry) Class III         45.0
# 682               213  Ordinary (Joisted Masonry) Class III         42.0
# 684               213  Ordinary (Joisted Masonry) Class III         10.0
# 4289              449                    Wood Frame Class V         16.0
# 4300              120  Ordinary (Joisted Masonry) Class III        104.0
# 4321              599  Ordinary (Joisted Masonry) Class III         45.0
# 4323              213  Ordinary (Joisted Masonry) Class III         69.0
# 4362              519                    Wood Frame Class V          1.0
#
#       SquareFeetK  predictions  average_OVAP
# 4          12.600    30.973998     31.592718
# 19         40.000    31.318906     31.592718
# 24        100.000    32.074181     31.592718
# 42          3.300    30.856930     31.592718
# 44         78.200    31.799764     31.592718
# 45          6.000    30.890917     31.592718
# 49          4.000    30.865742     31.592718
# 61         40.000    31.318906     31.592718
# 71          3.500    30.859448     31.592718
# 74          8.100    30.917352     31.592718
# 87         22.500    31.098618     31.592718
# 113         7.680    30.912065     31.592718
# 115        34.275    31.246840     31.592718
# 118         1.410    30.833139     31.592718
# 422       133.500    32.495875     31.592718
# 423         2.400    30.845601     31.592718
# 427        56.300    31.524089     31.592718
# 438         8.000    30.916093     31.592718
# 467       325.516    34.912954     31.592718
# 468        71.500    31.715425     31.592718
# 472       110.500    32.206353     31.592718
# 476       232.000    33.735784     31.592718
# 478        42.000    31.344082     31.592718
# 480        30.600    31.200580     31.592718
# 481         8.500    30.922387     31.592718
# 483        58.250    31.548635     31.592718
# 485        45.600    31.389398     31.592718
# 486         5.000    30.878330     31.592718
# 491        58.700    31.554300     31.592718
# 499        42.575    31.351320     31.592718
# 502        43.000    31.356670     31.592718
# 503        44.500    31.375552     31.592718
# 511       996.000    43.352943     31.592718
# 527       126.000    32.401466     31.592718
# 529         4.800    30.875812     31.592718
# 541         1.464    30.833819     31.592718
# 565        62.400    31.600875     31.592718
# 575        64.600    31.628569     31.592718
# 592        22.500    31.098618     31.592718
# 609        42.400    31.349117     31.592718
# 619         3.150    30.855042     31.592718
# 627       135.000    32.514757     31.592718
# 678        10.650    30.949451     31.592718
# 682        23.000    31.104912     31.592718
# 684        50.000    31.444785     31.592718
# 4289       76.200    31.774588     31.592718
# 4300       97.200    32.038934     31.592718
# 4321       40.330    31.323060     31.592718
# 4323       40.000    31.318906     31.592718
# 4362       15.400    31.009244     31.592718

# %%
## Predict OVAP Score from Square Footage and Building Age

## Make an instance of the LinearRegression class.
lr1 = LinearRegression()

## Make a list of feature columns that includes Square Feet and Building Age
feature_cols = ['SquareFeetK', 'BuildingAge']

# Set our feature columns to our X variable and what we want to predict, our OVAP score, to our y
X1 = super_true_data.loc[:, feature_cols]
y1 = super_true_data.loc[:, ['OVAP Score']]

lr1.fit(X1, y1)

super_true_data.loc[:, 'predictions_2_features'] = lr1.predict(X1)
# Out:
# C:\Users\theho\Anaconda3\lib\site-packages\pandas\core\indexing.py:337: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# C:\Users\theho\Anaconda3\lib\site-packages\pandas\core\indexing.py:517: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
from sklearn import metrics
import numpy as np

y_pred = super_true_data.loc[:, 'predictions']
y_pred_2_features = super_true_data.loc[:, 'predictions_2_features']
y_mean = super_true_data.loc[:, 'average_OVAP']

print('MSE of Using mean OVAP Score is',np.sqrt(metrics.mean_squared_error(y, y_mean)))
print('MSE of Using Square Footage is', np.sqrt(metrics.mean_squared_error(y, y_pred)))
print('MSE of Using Square Footage and Building Age is', np.sqrt(metrics.mean_squared_error(y, y_pred_2_features)))
# Out:
# MSE of Using mean OVAP Score is 4.35502080389
# MSE of Using Square Footage is 4.11573692044
# MSE of Using Square Footage and Building Age is 4.09191403112

# %%
## View coefficients for linear regression model that uses Square Footage and Building Age

list(zip(feature_cols,lr1.coef_.tolist()[0]))
# Out:
# [('SquareFeetK', 0.012529474927162143), ('BuildingAge', 0.0074285322765890935)]

# %%
## Visualize the data

import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline
plt.rcParams['figure.figsize'] = (8, 6)
plt.rcParams['font.size'] = 14
plt.style.use("fivethirtyeight")

## Create a scatter plot of Square Footage against OVAP Score

super_true_data.plot(kind='scatter', x='SquareFeetK', y='OVAP Score', alpha=0.2, figsize=(14,7)).set_xlim(0, 200)
# Out:
# (0, 200)
